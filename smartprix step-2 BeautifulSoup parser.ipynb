# %%
# smartprix step-2 BeautifulSoup parser

with open('smartprix.html','r',encoding = 'utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
containers = soup.find_all('div',{'class':"sm-product has-tag has-features has-actions"})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []
for i in containers:
    names.append(i.find('h2').text)
    
    prices.append(i.find('span',{'class':'price'}).text)
    
    ratings.append(i.find('b').text)

        
    x = i.find('ul',{'class':"sm-feat specs"}).find_all('li')
    
    try:
        sim.append(x[0].text)
    except:
        os.append(np.nan)
    
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    
    try:
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)

    

    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
os
# Out:
# ['Android v14',
#  'Android v14',
#  'Android v14',
#  'No FM Radio',
#  'Android v14',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'iOS v17',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v14',
#  'Android v11',
#  'Android v13',
#  'No FM Radio',
#  'Android v14',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v14',
#  'Android v14',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v14',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v11',
#  'iOS v17',
#  'Android v13',
#  'iOS v16',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'iOS v17',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'iOS v15',
#  'Bluetooth',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Bluetooth',
#  'No FM Radio',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v14',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'Android v12',
#  'Bluetooth',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'iOS v16',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Bluetooth',
#  'Android v14',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'iOS v17',
#  'Bluetooth',
#  'Android v11',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v10',
#  'Android v13',
#  'Android v11',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'iOS v17',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v14',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'Android v11',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v14',
#  'iOS v17',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'Bluetooth',
#  'Android v10',
#  'Android v10.0',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'No FM Radio',
#  'Android v14',
#  'Bluetooth',
#  nan,
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'iOS v15',
#  'Android v9.0 (Pie)',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'iOS v16',
#  'Android v12',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Memory Card Not Supported',
#  nan,
#  'Android v13',
#  'Bluetooth',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Android v10',
#  nan,
#  'iOS v17',
#  'Memory Card Supported, upto 128\u2009GB',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'No FM Radio',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Bluetooth',
#  'Android v13',
#  'No FM Radio',
#  'Android v11',
#  'No FM Radio',
#  nan,
#  'Android v13',
#  'iOS v17',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Bluetooth',
#  'Android v11',
#  'No FM Radio',
#  'Android v11',
#  'No FM Radio',
#  'Android v10.0',
#  'Android v11',
#  'Android v8.1 (Oreo)',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'v30',
#  'Android v12',
#  nan,
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'Bluetooth',
#  'Android v12',
#  '0.3\u2009MP Rear Camera',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Bluetooth',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'No FM Radio',
#  'Android v10.0',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Bluetooth',
#  nan,
#  'Android v13',
#  'Android v13',
#  'iOS v17',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Bluetooth',
#  'iOS v16',
#  'iOS v16',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Bluetooth',
#  'Android v12',
#  'Android v11',
#  'Memory Card Not Supported',
#  'Android v12',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Android v10.0',
#  nan,
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'iOS v17',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v12',
#  'Android v11.0',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v12',
#  'iOS v16',
#  'Android v12',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'No FM Radio',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'iOS v15',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'No FM Radio',
#  'Android v11',
#  'Android v10',
#  'Android v10',
#  'Android v10.0',
#  'Android v10.0',
#  'Android v11',
#  'Browser',
#  'Android v10',
#  'Android v11',
#  'Android v11',
#  'Android v9.0 (Pie)',
#  'Android v8 (Oreo)',
#  'Bluetooth',
#  'v30',
#  'Android v13',
#  'No FM Radio',
#  nan,
#  'No FM Radio',
#  nan,
#  'iOS v17',
#  'Android v13',
#  'Android v13',
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v13',
#  'Android v12',
#  'Android v12',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'No FM Radio',
#  'Android v11',
#  'Android v12',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  nan,
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'iOS v15.0',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v10',
#  'Android v11',
#  'RTOS (Series 30+)',
#  'No FM Radio',
#  'RTOS (Series 30+)',
#  'Android v10.0',
#  'Android v10',
#  'Android v10',
#  'Android v10',
#  'Android v10',
#  'Android v10.0',
#  'Android v10',
#  'Android v10.0',
#  'Android v10',
#  'Android v9.0 (Pie)',
#  'Android v9.0 (Pie)',
#  'Android v9.0 (Pie)',
#  'Android v9.0 (Pie)',
#  nan,
#  'No FM Radio',
#  nan,
#  'Android v13',
#  nan,
#  'Android v12',
#  'Android v13',
#  nan,
#  'Android v13',
#  'Memory Card Not Supported',
#  'Bluetooth',
#  'Android v12',
#  'Symbian v9.1',
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v12',
#  'Android v12',
#  'iOS v16',
#  'iOS v16',
#  'Android v12',
#  'Android v11',
#  'Memory Card Supported, upto 64\u2009GB',
#  'Android v12',
#  'Memory Card Not Supported',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v11',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v11',
#  'Android v10',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v10.0',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Bluetooth',
#  'Android v11',
#  'Bluetooth',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Android v10',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v10.0',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v10.0',
#  'Android v10.0',
#  'No FM Radio',
#  'Android v10',
#  'Android v10',
#  'Android v10',
#  'Bluetooth',
#  'Android v9 (Pie)',
#  'Android v9.0 (Pie)',
#  'Android v10',
#  'Memory Card Not Supported',
#  'Android v10.0',
#  'Android v9.0 (Pie)',
#  nan,
#  'Android v9.0 (Pie)',
#  'Android v9.0 (Pie)',
#  'Android v8.1 (Oreo)',
#  'Android v8.1 (Oreo)',
#  'Android v8.1 (Oreo)',
#  'Android v8.0 (Oreo)',
#  'Android v8.1 (Oreo)',
#  'Android v8.0 (Oreo)',
#  'No FM Radio',
#  'Android v7.1.1 (Nougat)',
#  'Android v7.1 (Nougat)',
#  'Android v7.1 (Nougat)',
#  'Android v5.1.1 (Lollipop)',
#  'Blackberry OS v10.3',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'Bluetooth',
#  'No FM Radio',
#  '0.8\u2009MP Rear Camera',
#  'No FM Radio',
#  'No FM Radio',
#  'Symbian v9.1',
#  'Nucleus OS',
#  'Nucleus OS',
#  'Nucleus OS',
#  'Bluetooth',
#  'No FM Radio',
#  'No FM Radio',
#  nan,
#  'Nucleus OS',
#  'Bluetooth',
#  nan,
#  'No FM Radio',
#  nan,
#  'v1.77',
#  'v1.77',
#  'v1.77',
#  nan,
#  'No FM Radio',
#  nan,
#  nan,
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'Symbian v9.1',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  nan,
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  'Bluetooth',
#  'Bluetooth',
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  nan,
#  'v1.77',
#  nan,
#  nan,
#  nan,
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  nan,
#  nan,
#  'Bluetooth',
#  'No FM Radio',
#  'v1',
#  'Bluetooth',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'v1',
#  'v1',
#  'v1',
#  nan,
#  nan,
#  'v1',
#  'Bluetooth',
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  'Bluetooth',
#  nan,
#  'Browser',
#  'Bluetooth',
#  'Bluetooth',
#  'iOS v17',
#  'Memory Card Supported',
#  'Android v12',
#  'Android v11',
#  'Bluetooth',
#  nan,
#  'Memory Card Supported, upto 32\u2009MB',
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  nan,
#  'Bluetooth',
#  'Android v13',
#  nan,
#  'Bluetooth',
#  nan,
#  'No FM Radio',
#  nan,
#  '0.3\u2009MP Rear Camera',
#  'Bluetooth',
#  nan,
#  'Memory Card Supported',
#  'Symbian',
#  '0.3\u2009MP Rear Camera',
#  'Android v12',
#  'Android v11',
#  'Android v13',
#  nan,
#  nan,
#  'No Rear Camera',
#  'v1.2',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  nan,
#  'Android v13',
#  'No Rear Camera',
#  nan,
#  'Symbian v9.1',
#  'Bluetooth',
#  nan,
#  'Browser',
#  nan,
#  'No FM Radio',
#  '1.3\u2009MP Rear Camera',
#  nan,
#  'Android v13',
#  'Android v13',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Android v13',
#  nan,
#  'Browser',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Android v12',
#  'Android',
#  'Bluetooth',
#  '0.3\u2009MP Rear Camera',
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  'No FM Radio',
#  nan,
#  'Android v10.0',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Bluetooth',
#  'Android v12',
#  'Browser',
#  'Bluetooth',
#  nan,
#  nan,
#  'Browser',
#  'Android v13',
#  'Bluetooth',
#  'Android v12',
#  nan,
#  'Android v12',
#  'Android v11.0',
#  'Android v12',
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v13',
#  nan,
#  nan,
#  nan,
#  'Bluetooth',
#  'Android v11.0',
#  nan,
#  'Bluetooth',
#  nan,
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Android v12',
#  nan,
#  nan,
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  '1.3\u2009MP Rear Camera',
#  'No FM Radio',
#  'Browser',
#  nan,
#  'Android v12',
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  'Android v12',
#  'Memory Card Supported',
#  'Bluetooth',
#  nan,
#  'Android v10.0',
#  nan,
#  nan,
#  'v0.1',
#  nan,
#  nan,
#  'Main Rear Camera',
#  nan,
#  'Android v12',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v12',
#  nan,
#  'No FM Radio',
#  nan,
#  'Android v12',
#  'Bluetooth',
#  nan,
#  'Android v12',
#  'Memory Card Supported',
#  nan,
#  nan,
#  nan,
#  'Mocor',
#  'Memory Card Supported, upto 16\u2009GB',
#  'Android v12',
#  'Android v10',
#  'Memory Card Supported',
#  'Android v10',
#  'Symbian v1',
#  'No FM Radio',
#  nan,
#  nan,
#  'Android v10',
#  'Symbian',
#  'No FM Radio',
#  'Android v11',
#  'Bluetooth',
#  nan,
#  'Symbian v1',
#  'Android v11',
#  'Android v11',
#  'Bluetooth',
#  '0.8\u2009MP Rear Camera',
#  'Android v11',
#  'Android v12',
#  'Memory Card Supported, upto 16\u2009GB',
#  'Memory Card Supported, upto 16\u2009GB',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No FM Radio',
#  nan,
#  'No FM Radio',
#  'No FM Radio',
#  nan,
#  'Android v12',
#  'Android v11',
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Bluetooth',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Memory Card Supported, upto 16\u2009GB',
#  'No FM Radio',
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  nan,
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  'Android v11',
#  'Android v11',
#  'Android v10',
#  nan,
#  'Memory Card (Hybrid), upto 32\u2009GB',
#  nan,
#  'Bluetooth',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bluetooth',
#  'Android v11',
#  'No FM Radio',
#  'Android v11',
#  nan,
#  nan,
#  'Android v10',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v11',
#  nan,
#  'Memory Card Supported, upto 16\u2009GB',
#  nan,
#  'Android v10',
#  'Android v11',
#  'Android v11',
#  '2\u2009MP Rear Camera',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  'Android v11',
#  nan,
#  nan,
#  'Bluetooth',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No FM Radio',
#  'Android v11',
#  nan,
#  'Bluetooth',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  'Android v11',
#  'Bluetooth',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v10.0',
#  ...]

# %%
for i in containers:
    x = i.find('ul',{'class':"sm-feat specs"}).find_all('li')
#     print('sim: ',x[0].text)
#     print('processor: ',x[1].text)
#     print('ram: ',x[2].text)
#     print('battery: ',x[3].text)
#     print('display: ',x[4].text)
#     print('camera: ',x[5].text)
#     print('card: ',x[6].text)
    try:
        print('os: ',x[7].text)
    except:
        continue
# Out:
# os:  Android v14
# os:  Android v14
# os:  Android v14
# os:  No FM Radio
# os:  Android v14
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  Android v12
# os:  iOS v17
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v14
# os:  Android v11
# os:  Android v13
# os:  No FM Radio
# os:  Android v14
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v14
# os:  Android v14
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v14
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v11
# os:  iOS v17
# os:  Android v13
# os:  iOS v16
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  iOS v17
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  iOS v15
# os:  Bluetooth
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v12
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Bluetooth
# os:  No FM Radio
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v14
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v13
# os:  Android v12
# os:  Android v12
# os:  Bluetooth
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  iOS v16
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Bluetooth
# os:  Android v14
# os:  Android v13
# os:  Memory Card Not Supported
# os:  Android v12
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  iOS v17
# os:  Bluetooth
# os:  Android v11
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  Android v12
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  Android v10
# os:  Android v13
# os:  Android v11
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  iOS v17
# os:  Android v13
# os:  Android v12
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v14
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v12
# os:  No FM Radio
# os:  Android v11
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  Android v14
# os:  iOS v17
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  Android v12
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Memory Card Not Supported
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  No FM Radio
# os:  No FM Radio
# os:  Bluetooth
# os:  Android v10
# os:  Android v10.0
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  No FM Radio
# os:  Android v14
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  iOS v15
# os:  Android v9.0 (Pie)
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  iOS v16
# os:  Android v12
# os:  No FM Radio
# os:  Android v13
# os:  Android v12
# os:  Android v12
# os:  Android v11
# os:  Android v11
# os:  Memory Card Not Supported
# os:  Android v13
# os:  Bluetooth
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Memory Card Not Supported
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v13
# os:  No FM Radio
# os:  Android v12
# os:  Android v11
# os:  Android v11
# os:  Android v10
# os:  iOS v17
# os:  Memory Card Supported, upto 128 GB
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  No FM Radio
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Bluetooth
# os:  Android v13
# os:  No FM Radio
# os:  Android v11
# os:  No FM Radio
# os:  Android v13
# os:  iOS v17
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Memory Card Not Supported
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Bluetooth
# os:  Android v11
# os:  No FM Radio
# os:  Android v11
# os:  No FM Radio
# os:  Android v10.0
# os:  Android v11
# os:  Android v8.1 (Oreo)
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  v30
# os:  Android v12
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  Android v12
# os:  Bluetooth
# os:  Android v12
# os:  0.3 MP Rear Camera
# os:  Memory Card Supported, upto 32 GB
# os:  Bluetooth
# os:  No FM Radio
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  No FM Radio
# os:  Android v10.0
# os:  No FM Radio
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  iOS v17
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  Bluetooth
# os:  iOS v16
# os:  iOS v16
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  No FM Radio
# os:  Android v11
# os:  Android v11
# os:  Bluetooth
# os:  Android v12
# os:  Android v11
# os:  Memory Card Not Supported
# os:  Android v12
# os:  No FM Radio
# os:  Android v11
# os:  Android v11
# os:  Android v10.0
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  Android v13
# os:  iOS v17
# os:  Android v13
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  Android v12
# os:  Android v11.0
# os:  Android v12
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v12
# os:  iOS v16
# os:  Android v12
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v11
# os:  Android v11
# os:  No FM Radio
# os:  Android v11
# os:  Android v12
# os:  Android v11
# os:  Android v12
# os:  Android v12
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  iOS v15
# os:  No FM Radio
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v12
# os:  Android v11
# os:  Android v11
# os:  No FM Radio
# os:  Android v11
# os:  Android v10
# os:  Android v10
# os:  Android v10.0
# os:  Android v10.0
# os:  Android v11
# os:  Browser
# os:  Android v10
# os:  Android v11
# os:  Android v11
# os:  Android v9.0 (Pie)
# os:  Android v8 (Oreo)
# os:  Bluetooth
# os:  v30
# os:  Android v13
# os:  No FM Radio
# os:  No FM Radio
# os:  iOS v17
# os:  Android v13
# os:  Android v13
# os:  Memory Card Supported, upto 32 GB
# os:  Android v13
# os:  Memory Card Not Supported
# os:  Android v13
# os:  Android v12
# os:  Android v12
# os:  Android v13
# os:  No FM Radio
# os:  Android v12
# os:  No FM Radio
# os:  Android v11
# os:  Android v12
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  Android v11
# os:  Android v11
# os:  Android v12
# os:  Android v12
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v12
# os:  Android v11
# os:  iOS v15.0
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v10
# os:  Android v11
# os:  RTOS (Series 30+)
# os:  No FM Radio
# os:  RTOS (Series 30+)
# os:  Android v10.0
# os:  Android v10
# os:  Android v10
# os:  Android v10
# os:  Android v10
# os:  Android v10.0
# os:  Android v10
# os:  Android v10.0
# os:  Android v10
# os:  Android v9.0 (Pie)
# os:  Android v9.0 (Pie)
# os:  Android v9.0 (Pie)
# os:  Android v9.0 (Pie)
# os:  No FM Radio
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  Android v13
# os:  Memory Card Not Supported
# os:  Bluetooth
# os:  Android v12
# os:  Symbian v9.1
# os:  Bluetooth
# os:  Bluetooth
# os:  Android v13
# os:  Memory Card Not Supported
# os:  Android v13
# os:  Android v12
# os:  Android v13
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Android v12
# os:  Memory Card Supported, upto 32 GB
# os:  Android v12
# os:  Android v12
# os:  iOS v16
# os:  iOS v16
# os:  Android v12
# os:  Android v11
# os:  Memory Card Supported, upto 64 GB
# os:  Android v12
# os:  Memory Card Not Supported
# os:  Memory Card Supported, upto 32 GB
# os:  Android v11
# os:  Android v12
# os:  Android v11
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  Android v11
# os:  Android v12
# os:  Android v12
# os:  Android v11
# os:  Android v11
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  Android v11
# os:  Android v10
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v10.0
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Bluetooth
# os:  Android v11
# os:  Bluetooth
# os:  Android v11
# os:  Android v12
# os:  Android v11
# os:  Android v10
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v10.0
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v10.0
# os:  Android v10.0
# os:  No FM Radio
# os:  Android v10
# os:  Android v10
# os:  Android v10
# os:  Bluetooth
# os:  Android v9 (Pie)
# os:  Android v9.0 (Pie)
# os:  Android v10
# os:  Memory Card Not Supported
# os:  Android v10.0
# os:  Android v9.0 (Pie)
# os:  Android v9.0 (Pie)
# os:  Android v9.0 (Pie)
# os:  Android v8.1 (Oreo)
# os:  Android v8.1 (Oreo)
# os:  Android v8.1 (Oreo)
# os:  Android v8.0 (Oreo)
# os:  Android v8.1 (Oreo)
# os:  Android v8.0 (Oreo)
# os:  No FM Radio
# os:  Android v7.1.1 (Nougat)
# os:  Android v7.1 (Nougat)
# os:  Android v7.1 (Nougat)
# os:  Android v5.1.1 (Lollipop)
# os:  Blackberry OS v10.3
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  Bluetooth
# os:  No FM Radio
# os:  0.8 MP Rear Camera
# os:  No FM Radio
# os:  No FM Radio
# os:  Symbian v9.1
# os:  Nucleus OS
# os:  Nucleus OS
# os:  Nucleus OS
# os:  Bluetooth
# os:  No FM Radio
# os:  No FM Radio
# os:  Nucleus OS
# os:  Bluetooth
# os:  No FM Radio
# os:  v1.77
# os:  v1.77
# os:  v1.77
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  Symbian v9.1
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  Bluetooth
# os:  Bluetooth
# os:  Bluetooth
# os:  Bluetooth
# os:  Bluetooth
# os:  Bluetooth
# os:  v1.77
# os:  Bluetooth
# os:  Bluetooth
# os:  Bluetooth
# os:  No FM Radio
# os:  v1
# os:  Bluetooth
# os:  v1
# os:  v1
# os:  v1
# os:  v1
# os:  Bluetooth
# os:  Bluetooth
# os:  Bluetooth
# os:  Bluetooth
# os:  Bluetooth
# os:  Browser
# os:  Bluetooth
# os:  Bluetooth
# os:  iOS v17
# os:  Memory Card Supported
# os:  Android v12
# os:  Android v11
# os:  Bluetooth
# os:  Memory Card Supported, upto 32 MB
# os:  Memory Card Supported, upto 32 GB
# os:  Bluetooth
# os:  Android v13
# os:  Bluetooth
# os:  No FM Radio
# os:  0.3 MP Rear Camera
# os:  Bluetooth
# os:  Memory Card Supported
# os:  Symbian
# os:  0.3 MP Rear Camera
# os:  Android v12
# os:  Android v11
# os:  Android v13
# os:  No Rear Camera
# os:  v1.2
# os:  Android v13
# os:  Bluetooth
# os:  Android v13
# os:  Android v13
# os:  No Rear Camera
# os:  Symbian v9.1
# os:  Bluetooth
# os:  Browser
# os:  No FM Radio
# os:  1.3 MP Rear Camera
# os:  Android v13
# os:  Android v13
# os:  Android v11
# os:  Android v13
# os:  Browser
# os:  Android v12
# os:  Android
# os:  Bluetooth
# os:  0.3 MP Rear Camera
# os:  Memory Card Supported, upto 32 GB
# os:  No FM Radio
# os:  Android v10.0
# os:  Memory Card Supported, upto 32 GB
# os:  Bluetooth
# os:  Android v12
# os:  Browser
# os:  Bluetooth
# os:  Browser
# os:  Android v13
# os:  Bluetooth
# os:  Android v12
# os:  Android v12
# os:  Android v11.0
# os:  Android v12
# os:  Memory Card Supported, upto 32 GB
# os:  Android v13
# os:  Bluetooth
# os:  Android v11.0
# os:  Bluetooth
# os:  Memory Card Supported, upto 32 GB
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  Android v12
# os:  1.3 MP Rear Camera
# os:  No FM Radio
# os:  Browser
# os:  Android v12
# os:  Memory Card Supported, upto 32 GB
# os:  Android v12
# os:  Memory Card Supported
# os:  Bluetooth
# os:  Android v10.0
# os:  v0.1
# os:  Main Rear Camera
# os:  Android v12
# os:  Memory Card Supported, upto 32 GB
# os:  Android v12
# os:  No FM Radio
# os:  Android v12
# os:  Bluetooth
# os:  Android v12
# os:  Memory Card Supported
# os:  Mocor
# os:  Memory Card Supported, upto 16 GB
# os:  Android v12
# os:  Android v10
# os:  Memory Card Supported
# os:  Android v10
# os:  Symbian v1
# os:  No FM Radio
# os:  Android v10
# os:  Symbian
# os:  No FM Radio
# os:  Android v11
# os:  Bluetooth
# os:  Symbian v1
# os:  Android v11
# os:  Android v11
# os:  Bluetooth
# os:  0.8 MP Rear Camera
# os:  Android v11
# os:  Android v12
# os:  Memory Card Supported, upto 16 GB
# os:  Memory Card Supported, upto 16 GB
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  No FM Radio
# os:  No FM Radio
# os:  No FM Radio
# os:  Android v12
# os:  Android v11
# os:  Memory Card Supported, upto 32 GB
# os:  Android v11
# os:  Android v12
# os:  Android v11
# os:  Bluetooth
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Memory Card Supported, upto 16 GB
# os:  No FM Radio
# os:  Memory Card Supported, upto 32 GB
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v10
# os:  Memory Card (Hybrid), upto 32 GB
# os:  Bluetooth
# os:  Android v11
# os:  Bluetooth
# os:  Android v11
# os:  No FM Radio
# os:  Android v11
# os:  Android v10
# os:  Memory Card Supported, upto 32 GB
# os:  Android v11
# os:  Memory Card Supported, upto 16 GB
# os:  Android v10
# os:  Android v11
# os:  Android v11
# os:  2 MP Rear Camera
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Bluetooth
# os:  Android v11
# os:  No FM Radio
# os:  Android v11
# os:  Bluetooth
# os:  Android v11
# os:  Android v11
# os:  Bluetooth
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Android v10.0
# os:  Browser
# os:  Android v11
# os:  Android v11
# os:  Android v11
# os:  Bluetooth
# os:  Android v10
# os:  Android v11
# os:  Android v11
# os:  No FM Radio
# os:  Android v11
# os:  1.3 MP Rear Camera
# os:  Android v11
# os:  Android v11
# os:  Android v10

# %%
for i in containers:
    x = i.find('ul',{'class':"sm-feat specs"}).find_all('li')
#     print('sim: ',x[0].text)
#     print('processor: ',x[1].text)
#     print('ram: ',x[2].text)
#     print('battery: ',x[3].text)
#     print('display: ',x[4].text)
#     print('camera: ',x[5].text)
#     print('card: ',x[6].text)
    try:
        print('os: ',x[7].text)
    except:
        continue
# Out:
# ['2500\u2009mAh Battery']

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     1020 non-null   object
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1014 non-null   object
#  9   card       965 non-null    object
#  10  os         853 non-null    object
# dtypes: object(11)
# memory usage: 87.8+ KB

# %%
os
# Out:
# ['Android v14',
#  'Android v14',
#  'Android v14',
#  'No FM Radio',
#  'Android v14',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'iOS v17',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v14',
#  'Android v11',
#  'Android v13',
#  'No FM Radio',
#  'Android v14',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v14',
#  'Android v14',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v14',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v11',
#  'iOS v17',
#  'Android v13',
#  'iOS v16',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'iOS v17',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'iOS v15',
#  'Bluetooth',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Bluetooth',
#  'No FM Radio',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v14',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'Android v12',
#  'Bluetooth',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'iOS v16',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Bluetooth',
#  'Android v14',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'iOS v17',
#  'Bluetooth',
#  'Android v11',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v10',
#  'Android v13',
#  'Android v11',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'iOS v17',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v14',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'Android v11',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v14',
#  'iOS v17',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'Bluetooth',
#  'Android v10',
#  'Android v10.0',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'No FM Radio',
#  'Android v14',
#  'Bluetooth',
#  nan,
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'iOS v15',
#  'Android v9.0 (Pie)',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'iOS v16',
#  'Android v12',
#  'No FM Radio',
#  'Android v13',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Memory Card Not Supported',
#  nan,
#  'Android v13',
#  'Bluetooth',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Android v10',
#  nan,
#  'iOS v17',
#  'Memory Card Supported, upto 128\u2009GB',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'No FM Radio',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Bluetooth',
#  'Android v13',
#  'No FM Radio',
#  'Android v11',
#  'No FM Radio',
#  nan,
#  'Android v13',
#  'iOS v17',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Bluetooth',
#  'Android v11',
#  'No FM Radio',
#  'Android v11',
#  'No FM Radio',
#  'Android v10.0',
#  'Android v11',
#  'Android v8.1 (Oreo)',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'v30',
#  'Android v12',
#  nan,
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v13',
#  'Android v12',
#  'Bluetooth',
#  'Android v12',
#  '0.3\u2009MP Rear Camera',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Bluetooth',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'No FM Radio',
#  'Android v10.0',
#  'No FM Radio',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Bluetooth',
#  nan,
#  'Android v13',
#  'Android v13',
#  'iOS v17',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Bluetooth',
#  'iOS v16',
#  'iOS v16',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Bluetooth',
#  'Android v12',
#  'Android v11',
#  'Memory Card Not Supported',
#  'Android v12',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Android v10.0',
#  nan,
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  'Android v13',
#  'Android v13',
#  'iOS v17',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v12',
#  'Android v11.0',
#  'Android v12',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v12',
#  'iOS v16',
#  'Android v12',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'No FM Radio',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'iOS v15',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'No FM Radio',
#  'Android v11',
#  'Android v10',
#  'Android v10',
#  'Android v10.0',
#  'Android v10.0',
#  'Android v11',
#  'Browser',
#  'Android v10',
#  'Android v11',
#  'Android v11',
#  'Android v9.0 (Pie)',
#  'Android v8 (Oreo)',
#  'Bluetooth',
#  'v30',
#  'Android v13',
#  'No FM Radio',
#  nan,
#  'No FM Radio',
#  nan,
#  'iOS v17',
#  'Android v13',
#  'Android v13',
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v13',
#  'Android v12',
#  'Android v12',
#  'Android v13',
#  'No FM Radio',
#  'Android v12',
#  'No FM Radio',
#  'Android v11',
#  'Android v12',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  nan,
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'iOS v15.0',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v10',
#  'Android v11',
#  'RTOS (Series 30+)',
#  'No FM Radio',
#  'RTOS (Series 30+)',
#  'Android v10.0',
#  'Android v10',
#  'Android v10',
#  'Android v10',
#  'Android v10',
#  'Android v10.0',
#  'Android v10',
#  'Android v10.0',
#  'Android v10',
#  'Android v9.0 (Pie)',
#  'Android v9.0 (Pie)',
#  'Android v9.0 (Pie)',
#  'Android v9.0 (Pie)',
#  nan,
#  'No FM Radio',
#  nan,
#  'Android v13',
#  nan,
#  'Android v12',
#  'Android v13',
#  nan,
#  'Android v13',
#  'Memory Card Not Supported',
#  'Bluetooth',
#  'Android v12',
#  'Symbian v9.1',
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  'Android v13',
#  'Memory Card Not Supported',
#  'Android v13',
#  'Android v12',
#  'Android v13',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Android v12',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v12',
#  'Android v12',
#  'iOS v16',
#  'iOS v16',
#  'Android v12',
#  'Android v11',
#  'Memory Card Supported, upto 64\u2009GB',
#  'Android v12',
#  'Memory Card Not Supported',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v11',
#  'Android v12',
#  'Android v12',
#  'Android v11',
#  'Android v11',
#  'Android v12',
#  'No FM Radio',
#  'Android v12',
#  'Android v11',
#  'Android v10',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v10.0',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Bluetooth',
#  'Android v11',
#  'Bluetooth',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Android v10',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v10.0',
#  'No FM Radio',
#  'No FM Radio',
#  'Android v10.0',
#  'Android v10.0',
#  'No FM Radio',
#  'Android v10',
#  'Android v10',
#  'Android v10',
#  'Bluetooth',
#  'Android v9 (Pie)',
#  'Android v9.0 (Pie)',
#  'Android v10',
#  'Memory Card Not Supported',
#  'Android v10.0',
#  'Android v9.0 (Pie)',
#  nan,
#  'Android v9.0 (Pie)',
#  'Android v9.0 (Pie)',
#  'Android v8.1 (Oreo)',
#  'Android v8.1 (Oreo)',
#  'Android v8.1 (Oreo)',
#  'Android v8.0 (Oreo)',
#  'Android v8.1 (Oreo)',
#  'Android v8.0 (Oreo)',
#  'No FM Radio',
#  'Android v7.1.1 (Nougat)',
#  'Android v7.1 (Nougat)',
#  'Android v7.1 (Nougat)',
#  'Android v5.1.1 (Lollipop)',
#  'Blackberry OS v10.3',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'Bluetooth',
#  'No FM Radio',
#  '0.8\u2009MP Rear Camera',
#  'No FM Radio',
#  'No FM Radio',
#  'Symbian v9.1',
#  'Nucleus OS',
#  'Nucleus OS',
#  'Nucleus OS',
#  'Bluetooth',
#  'No FM Radio',
#  'No FM Radio',
#  nan,
#  'Nucleus OS',
#  'Bluetooth',
#  nan,
#  'No FM Radio',
#  nan,
#  'v1.77',
#  'v1.77',
#  'v1.77',
#  nan,
#  'No FM Radio',
#  nan,
#  nan,
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  'Symbian v9.1',
#  'No FM Radio',
#  'No FM Radio',
#  'No FM Radio',
#  nan,
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  'Bluetooth',
#  'Bluetooth',
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  nan,
#  'v1.77',
#  nan,
#  nan,
#  nan,
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  nan,
#  nan,
#  'Bluetooth',
#  'No FM Radio',
#  'v1',
#  'Bluetooth',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'v1',
#  'v1',
#  'v1',
#  nan,
#  nan,
#  'v1',
#  'Bluetooth',
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  nan,
#  'Bluetooth',
#  'Bluetooth',
#  nan,
#  'Browser',
#  'Bluetooth',
#  'Bluetooth',
#  'iOS v17',
#  'Memory Card Supported',
#  'Android v12',
#  'Android v11',
#  'Bluetooth',
#  nan,
#  'Memory Card Supported, upto 32\u2009MB',
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  nan,
#  'Bluetooth',
#  'Android v13',
#  nan,
#  'Bluetooth',
#  nan,
#  'No FM Radio',
#  nan,
#  '0.3\u2009MP Rear Camera',
#  'Bluetooth',
#  nan,
#  'Memory Card Supported',
#  'Symbian',
#  '0.3\u2009MP Rear Camera',
#  'Android v12',
#  'Android v11',
#  'Android v13',
#  nan,
#  nan,
#  'No Rear Camera',
#  'v1.2',
#  'Android v13',
#  'Bluetooth',
#  'Android v13',
#  nan,
#  'Android v13',
#  'No Rear Camera',
#  nan,
#  'Symbian v9.1',
#  'Bluetooth',
#  nan,
#  'Browser',
#  nan,
#  'No FM Radio',
#  '1.3\u2009MP Rear Camera',
#  nan,
#  'Android v13',
#  'Android v13',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Android v13',
#  nan,
#  'Browser',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Android v12',
#  'Android',
#  'Bluetooth',
#  '0.3\u2009MP Rear Camera',
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  'No FM Radio',
#  nan,
#  'Android v10.0',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Bluetooth',
#  'Android v12',
#  'Browser',
#  'Bluetooth',
#  nan,
#  nan,
#  'Browser',
#  'Android v13',
#  'Bluetooth',
#  'Android v12',
#  nan,
#  'Android v12',
#  'Android v11.0',
#  'Android v12',
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v13',
#  nan,
#  nan,
#  nan,
#  'Bluetooth',
#  'Android v11.0',
#  nan,
#  'Bluetooth',
#  nan,
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Android v12',
#  nan,
#  nan,
#  'No FM Radio',
#  'Android v12',
#  'Android v12',
#  '1.3\u2009MP Rear Camera',
#  'No FM Radio',
#  'Browser',
#  nan,
#  'Android v12',
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  'Android v12',
#  'Memory Card Supported',
#  'Bluetooth',
#  nan,
#  'Android v10.0',
#  nan,
#  nan,
#  'v0.1',
#  nan,
#  nan,
#  'Main Rear Camera',
#  nan,
#  'Android v12',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v12',
#  nan,
#  'No FM Radio',
#  nan,
#  'Android v12',
#  'Bluetooth',
#  nan,
#  'Android v12',
#  'Memory Card Supported',
#  nan,
#  nan,
#  nan,
#  'Mocor',
#  'Memory Card Supported, upto 16\u2009GB',
#  'Android v12',
#  'Android v10',
#  'Memory Card Supported',
#  'Android v10',
#  'Symbian v1',
#  'No FM Radio',
#  nan,
#  nan,
#  'Android v10',
#  'Symbian',
#  'No FM Radio',
#  'Android v11',
#  'Bluetooth',
#  nan,
#  'Symbian v1',
#  'Android v11',
#  'Android v11',
#  'Bluetooth',
#  '0.8\u2009MP Rear Camera',
#  'Android v11',
#  'Android v12',
#  'Memory Card Supported, upto 16\u2009GB',
#  'Memory Card Supported, upto 16\u2009GB',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No FM Radio',
#  nan,
#  'No FM Radio',
#  'No FM Radio',
#  nan,
#  'Android v12',
#  'Android v11',
#  nan,
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v11',
#  'Android v12',
#  'Android v11',
#  'Bluetooth',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Memory Card Supported, upto 16\u2009GB',
#  'No FM Radio',
#  'Memory Card Supported, upto 32\u2009GB',
#  nan,
#  nan,
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  'Android v11',
#  'Android v11',
#  'Android v10',
#  nan,
#  'Memory Card (Hybrid), upto 32\u2009GB',
#  nan,
#  'Bluetooth',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  'Bluetooth',
#  'Android v11',
#  'No FM Radio',
#  'Android v11',
#  nan,
#  nan,
#  'Android v10',
#  'Memory Card Supported, upto 32\u2009GB',
#  'Android v11',
#  nan,
#  'Memory Card Supported, upto 16\u2009GB',
#  nan,
#  'Android v10',
#  'Android v11',
#  'Android v11',
#  '2\u2009MP Rear Camera',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  'Android v11',
#  nan,
#  nan,
#  'Bluetooth',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'No FM Radio',
#  'Android v11',
#  nan,
#  'Bluetooth',
#  'Android v11',
#  nan,
#  nan,
#  nan,
#  'Android v11',
#  'Bluetooth',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v11',
#  'Android v10.0',
#  ...]

# %%
df
# Out:
#                                        model      price rating  \
# 0                       Motorola Moto G34 5G    ₹10,999     75
# 1                   Samsung Galaxy S24 Ultra  ₹1,29,999     95
# 2                               OPPO Reno 11    ₹29,999     88
# 3                Xiaomi Redmi Note 13 Pro 5G    ₹25,990     84
# 4     Motorola Moto G34 5G (8GB RAM + 128GB)    ₹11,999     79
# ...                                      ...        ...    ...
# 1015                              Realme C25     ₹8,890     65
# 1016                                 Giva G5       ₹850      7
# 1017       Realme Narzo 30A (4GB RAM + 64GB)     ₹9,999     67
# 1018                           Micromax X743     ₹1,275      7
# 1019                                 Giva G3       ₹750      7
#
#                                                     sim  \
# 0              Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# 1         Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 2     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 3        Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 4              Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi
# ...                                                 ...
# 1015                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1016                                           Dual Sim
# 1017                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1018                                           Dual Sim
# 1019                                           Dual Sim
#
#                                               processor  \
# 0          Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1       Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 2          Dimensity 7050, Octa Core, 2.6 GHz Processor
# 3     Snapdragon 7s Gen 2, Octa Core, 2.4 GHz Processor
# 4          Snapdragon 695, Octa Core, 2.2 GHz Processor
# ...                                                 ...
# 1015              Helio G70, Octa Core, 2 GHz Processor
# 1016                                    1 MHz Processor
# 1017             Helio  G85, Octa Core, 2 GHz Processor
# 1018                                  1.2 MHz Processor
# 1019                                    1 MHz Processor
#
#                             ram                                  battery  \
# 0      4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 1     12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 45W Fast Charging
# 2      8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 67W Fast Charging
# 3      8 GB RAM, 128 GB inbuilt  5100 mAh Battery with 67W Fast Charging
# 4      8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# ...                         ...                                      ...
# 1015    4 GB RAM, 64 GB inbuilt  6000 mAh Battery with 18W Fast Charging
# 1016   32 MB RAM, 32 MB inbuilt                          998 mAh Battery
# 1017    4 GB RAM, 64 GB inbuilt                         6000 mAh Battery
# 1018   32 MB RAM, 32 MB inbuilt                         1000 mAh Battery
# 1019   32 MB RAM, 32 MB inbuilt                         1000 mAh Battery
#
#                                                 display  \
# 0     6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# 1     6.8 inches, 1440 x 3120 px, 120 Hz Display wit...
# 2     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 3     6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 4     6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.5 inches, 1600 x 720 px Display with Water D...
# 1016                   1.8 inches, 240 x 320 px Display
# 1017  6.51 inches, 720 x 1600 px Display with Water ...
# 1018                   2.4 inches, 240 x 320 px Display
# 1019                   1.8 inches, 128 x 160 px Display
#
#                                                  camera  \
# 0           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# 1                 200 MP Quad Rear & 12 MP Front Camera
# 2     50 MP + 32 MP + 8 MP Triple Rear & 32 MP Front...
# 3     200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 4           50 MP + 2 MP Dual Rear & 16 MP Front Camera
# ...                                                 ...
# 1015  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 1016                                 0.3 MP Rear Camera
# 1017         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 1018                                0.03 MP Rear Camera
# 1019                                 0.3 MP Rear Camera
#
#                                     card           os
# 0        Memory Card (Hybrid), upto 1 TB  Android v14
# 1              Memory Card Not Supported  Android v14
# 2                   Memory Card (Hybrid)  Android v14
# 3                            Android v13  No FM Radio
# 4        Memory Card (Hybrid), upto 1 TB  Android v14
# ...                                  ...          ...
# 1015  Memory Card Supported, upto 256 GB  Android v11
# 1016                         No FM Radio          NaN
# 1017  Memory Card Supported, upto 256 GB  Android v10
# 1018                         No FM Radio          NaN
# 1019                         No FM Radio          NaN
#
# [1020 rows x 11 columns]
