# %%
# to see  see all the row so to solve it
pd.set_option('display.max_rows',None)

# %%
# to reset above method
pd.reset_option("display.max_rows")
pd.reset_option("display.min_rows")
pd.reset_option("display.max_columns")
pd.reset_option("display.html.border")
pd.reset_option("io.excel.xlsm.reader")

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('smartphones.csv')

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %% [markdown]
# ### Data Assessing
#
#     Quality Issues:
#     1.model - some brands are written differently like OPPO in model column 'consistency'
#     2.price - has '₹' which makes it object datatype by which we can't perform mathematical calculations 'validity'
#     3.price - has ',' between numbers which makes it object datatype by which we can't perform mathematical calculations
#               'validity'
#     4.price - phone Namotel has a price of 99 'accuracy'
#     5.os - missing values 'completeness'
#     6.processor - has some incorrect values for some samsung phones rows-(642,647,649,659,667,701,750,759,819,859,883,884,
#                                                                           919,927,929,932,990,1002) 'validity'
#     7.There is ipod on row 756 'validity'
#     8.ram - incorrect values in rows-(441,485,534,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,
#                                          990,1002) 'validity'
#     9.battery - incorrect values in rows-(113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,819
#                                          855,859,884,915,916,927,929,932,990,1002) 'validity'
#     7.card - some values contains os information 'validity'
#     8.os - incorrect values 'validity'
#     10.display - sometimes frequency is not available 'completenesss'
#     11.display - incorrect values in rows-(378,441 450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,
#                                           884,915,916,927,929,932,990,1002) 'validity'
#     12.certain phones are foldable and information is scattered 'validity'
#     13.camera - words like Dual, Triple and Quard are used to represent number of cameras and front and rare cameras are
#                 seperated by '&' 'this is not an issue this is an observation'
#     14.camera - problem with rows-(100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,
#                                   575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,
#                                    846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016) 'validity'
#     15.card - sometimes contains info about os and camera 'validity'
#     16.os - sometimes contains info about bluetooth and fm radio 'validity'
#     17.os - issue with rows(324,378)
#     18.os - sometimes contains os version name like lollipop 'consistency'
#     19.missing values in camera,card and os completeness
#     20.datatype of price and rating is incorrect 'validity'
#
#     Tidiness Issues:
#     1.sim - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
#     2.ram - can be split into 2 cols RAM and ROM
#     3.processor - can be split into processor name, cores and cpu speed
#     4.battery - can be split into battery capacity, fast_charging_available
#     5.display - can be split into size, resolution_width, resolution_height and frequency
#     6.camera - can be split into front and rare camera
#     7.card - can be split into supported, extended_upto

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
df['os'].value_counts()
# Out:
# os
# Android v12                           287
# Android v11                           233
# No FM Radio                           192
# Android v10                            58
# Android v13                            45
# Bluetooth                              38
# Android v9.0 (Pie)                     27
# Android v10.0                          22
# iOS v16                                14
# iOS v15                                10
# Android v8.1 (Oreo)                    10
# Memory Card Not Supported               6
# Android v11.0                           4
# Browser                                 4
# Android v8.0 (Oreo)                     4
# iOS v13                                 3
# Android v6.0 (Marshmallow)              3
# iOS v15.0                               3
# Memory Card Supported, upto 32 GB       3
# Android v5.1.1 (Lollipop)               2
# Memory Card (Hybrid), upto 2 TB         2
# Harmony v2.0                            2
# ...

# %%
# make a copy
df1 = df.copy()

# %%
df1
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df1['price'] = df1['price'].str.replace('₹','').str.replace(',','').astype('int')

# %%
df1
# Out:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df1 = df1.reset_index()

# %%
df1['index'] = df1['index']+2

# %%
df1
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,990,1002))
ram_rows = set((441,485,534,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,
                    916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,
                    1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,
                   615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,
                   916,927,929,932,945,956,990,995,1002,1016))

# %%
df1[df1['index'].isin(processor_rows|ram_rows|battery_rows|display_rows|camera_rows)]
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1[df1['index'].isin(processor_rows&ram_rows&battery_rows&display_rows&camera_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 988     990     Nokia 5310 Dual Sim   3399     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# ...

# %%
df1[df1['index'].isin(processor_rows&ram_rows&battery_rows&display_rows&camera_rows)]['price'].mean()
# Out:
# 2599.214285714286

# %%
# after observing above data there are no smartphones under 3400rupees and here we want is smartphone data so
df1 = df1[df1['price'] >= 3400]

# %%
df1[df1['index'].isin(processor_rows&ram_rows&battery_rows&display_rows&camera_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                                display                             camera  \
# 645  Memory Card Supported, upto 32 GB                         Kaios v3.0
# ...

# %%
df1[df1['index'].isin(processor_rows)]
# Out:
#      index                   model  price  rating  \
# 645    647         Nokia 2760 Flip   5490     NaN
# 857    859             LG Folder 2  11999     NaN
# 882    884  Nokia 5710 XpressAudio   4799     NaN
# 925    927           Nokia 3310 4G   3999     NaN
#
#                                 sim                   processor  \
# 645         Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 857       Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 882                Dual Sim, 3G, 4G                     No Wifi
# 925  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
#
#                                   ram                           battery  \
# 645  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 857                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 882                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 925                  1200 mAh Battery  2.4 inches, 240 x 320 px Display
#
# ...

# %%
# below index number phones are feature phones(not smartphones) so let's drop them
df1.drop([645,857,882,925],inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\659065605.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([645,857,882,925],inplace = True)

# %%
df1[df1['index'].isin(processor_rows)]
# Out:
# Empty DataFrame
# Columns: [index, model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %%
df1[df1['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 582    584                     Nokia 8210 4G    3749     NaN
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 582                                 Dual Sim, 3G, 4G
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 582                                           No Wifi     Unisoc T107
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
# 582                48 MB RAM, 128 MB inbuilt
#
# ...

# %%
# it is not a smartphone
df1.drop(582,inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\1825133570.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(582,inplace = True)

# %%
df1[df1['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 439    441            Apple iPhone SE 3 2022   43900     NaN
# 483    485  Huawei Mate 50 RS Porsche Design  239999    81.0
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 483  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 483  4700 mAh Battery with 66W Fast Charging
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 483  6.74 inches, 1212 x 2616 px, 120 Hz Display
#
#                                                 camera  \
# ...

# %%
df1[df1['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376    378               Nokia 2660 Flip    4649     NaN
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 754    756    Apple iPod Touch (7th Gen)   18900     NaN
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# they are not smartphones
df1.drop([376,754],inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\2384066790.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([376,754],inplace = True)

# %%
# as you can see from battery to till last column value need a one right shift
df1[df1['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# as we don't any problem in original dataframe even by accident
temp_df = df1[df1['index'].isin(battery_rows)]

# %%
# all rows and columns from 7 to till end and a single right shift,axis = 1 means row wise shifting
temp_df.iloc[:,7:].shift(1,axis = 1)
# Out:
#     battery                                            display  \
# 111    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 149    None                 5.4 inches, 1080 x 2340 px Display
# 307    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 363    None                 5.4 inches, 1080 x 2340 px Display
# 439    None                  4.7 inches, 750 x 1334 px Display
# 448    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 628    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 762    None                  6.1 inches, 750 x 1580 px Display
# 853    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 913    None                 5.4 inches, 1080 x 2340 px Display
# 914    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# ...

# %%
temp_df.iloc[:,7:].shift(1,axis = 1).values
# Out:
# array([[None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '4.7 inches, 750\u2009x\u20091334\u2009px Display',
#         '12\u2009MP Rear & 7\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
# ...

# %%
x = temp_df.iloc[:,7:].shift(1,axis = 1).values

# %%
temp_df.index
# Out:
# Index([111, 149, 307, 363, 439, 448, 628, 762, 853, 913, 914], dtype='int64')

# %%
x_index = temp_df.index

# %%
# in rows(is temp_df.index) and columns(is temp_df.columns[7:]) of original data we are storing x vlaues
df1.loc[temp_df.index,temp_df.columns[7:]] = x

# %%
# check
df1[df1['index'].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 307    309       Apple iPhone 12 (128GB)   55999    75.0
# 363    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 853    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
df1[df1['index'].isin(display_rows)]
# Out:
#      index                         model   price  rating  \
# 439    441        Apple iPhone SE 3 2022   43900     NaN
# 448    450           Apple iPhone 15 Pro  130990    75.0
# 628    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 762    764             Apple iPhone SE 4   49990    60.0
# 913    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 628  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 762  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 913  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# ...

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 155     157                           Nokia 2780 Flip    4990     NaN
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 271     273                         Nokia 2720 V Flip    6199     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# ...

# %%
# in above output found few feature phones lets drop them
df1.drop([155,271],inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\456148504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([155,271],inplace = True)

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
temp_df = df1[df1['index'].isin(camera_rows)]

# %%
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]

# %%
# as you can see in the output that the only correction we need is to shift card column values into camera column
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
# rows temp_df.index,column camera
df1.loc[temp_df.index,'camera'] = temp_df['card'].values

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# ...

# %%
df1['camera'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1       64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2       50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3       50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4       108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#                               ...
# 1015    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016    48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018    108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019    64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# Name: camera, Length: 982, dtype: object>

# %%
df1['camera'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1       64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2       50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3       50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4       108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#                               ...
# 1015    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016    48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017    64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018    108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019    64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
# Name: camera, Length: 982, dtype: object>

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB                                       171
# Memory Card Not Supported                                              123
# Android v12                                                            107
# Memory Card Supported, upto 512 GB                                     105
# Memory Card (Hybrid), upto 1 TB                                         91
# Memory Card Supported                                                   89
# Memory Card Supported, upto 256 GB                                      87
# Android v13                                                             46
# Android v11                                                             41
# Memory Card (Hybrid)                                                    30
# Memory Card (Hybrid), upto 256 GB                                       13
# Android v10                                                             11
# ...

# %%
# let us replace camera values with Memory Card Not Supported in card column
temp_df = df1[df1['card'].str.contains('MP')]

# %%
# in loc gave temp_df as rows and card as column
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB       171
# Memory Card Not Supported              149
# Android v12                            107
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Android v13                             46
# Android v11                             41
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Android v10                             11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 128 GB        3
# Android v9.0 (Pie)                       2
# Android v12.1                            1
# Memory Card Supported, upto 1000 GB      1
# iOS v10                                  1
# ...

# %%
# as you can see in above output ther are only two types of values in card one is memory related and another one is os 
temp_df = df1[~df1['card'].str.contains('Memory Card')]

# %%
# in loc temp_df.index is rows and card is column
df1.loc[temp_df.index,'os'] = temp_df['card'].values

# %%
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              362
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       6
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %%
# os column contains data of memory card in it 
df1['os'].value_counts()
# Out:
# os
# Android v12                           394
# Android v11                           274
# Android v13                            91
# Android v10                            69
# Android v9.0 (Pie)                     29
# Android v10.0                          23
# iOS v16                                15
# iOS v15                                12
# Android v8.1 (Oreo)                    10
# iOS v14                                 6
# Memory Card Not Supported               6
# Android v11.0                           4
# Android v8.0 (Oreo)                     4
# iOS v13                                 4
# iOS v15.0                               3
# Android v6.0 (Marshmallow)              2
# Memory Card (Hybrid), upto 256 GB       2
# Memory Card (Hybrid), upto 2 TB         2
# HarmonyOS v2.0                          2
# Android v5.1.1 (Lollipop)               2
# Harmony v2.0                            2
# EMUI v12                                2
# ...

# %%
temp_df = df1[df1['os'].str.contains('Memory Card')]

# %%
df1.loc[temp_df.index,'card'] = temp_df['os'].values

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              354
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      89
# Memory Card (Hybrid)                    31
# Memory Card (Hybrid), upto 256 GB       15
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       7
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 2 TB          3
# Memory Card Supported, upto 1000 GB      1
# Name: count, dtype: int64

# %%
temp_df = df1[df1['os'].str.contains('Memory Card')]

# %%
# in loc we gave temp_df.index as rows and os column as column
df1.loc[temp_df.index,'os'] = np.nan

# %%
# as there are Nan values it is not showing result
df1[df1['os'].str.contains('Bluetooth')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 # as there are Nan values it is not showing result
# ----> 2 df1[df1['os'].str.contains('Bluetooth')]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4092, in DataFrame.__getitem__(self, key)
#    4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
# -> 4092 if com.is_bool_indexer(key):
#    4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
# ...

# %%
df1[df1['os'] == 'Bluetooth']
# Out:
#      index          model  price  rating                      sim  \
# 486    488  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
#
#                                          processor                       ram  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  512 MB RAM, 4 GB inbuilt
#
#               battery                           display            camera  \
# 486  1500 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
#
#                       card         os
# 486  Memory Card Supported  Bluetooth

# %%
temp_df = df1[df1['os'] == 'Bluetooth']

# %%
# in loc we gave temp_df.index as rows and os column as column
df1.loc[temp_df.index,'os'] = np.nan

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                        394
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# Android v11.0                        4
# iOS v13                              4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# HarmonyOS v2.0                       2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# Harmony v2.0                         2
# EMUI v12                             2
# Android v12.1                        2
# iOS v14.0                            2
# HarmonyOS                            1
# Android                              1
# Hongmeng OS v4.0                     1
# ...

# %%
df1.shape
# Out:
# (982, 12)

# %%
# stared with 1020 rows now 982
# we still have 96% data
982/1020*100
# Out:
# 96.27450980392157

# %%
df1['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                               317
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      268
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           155
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster                54
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster           52
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                           46
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    46
# Dual Sim, 3G, 4G, Wi-Fi                                        7
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                  7
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      7
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster                5
# Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                          4
# Single Sim, 3G, 4G, VoLTE, Wi-Fi                               3
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                       3
# ...

# %%
df1['processor'].value_counts()
# Out:
# processor
# Dimensity 700 5G, Octa Core, 2.2 GHz Processor      29
# Helio P35, Octa Core, 2.3 GHz Processor             27
# Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor    26
# Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor     23
# Snapdragon 695, Octa Core, 2.2 GHz Processor        23
#                                                     ..
# Snapdragon  720G , Octa Core, 2.3 GHz Processor      1
# Snapdragon 888+ , Octa Core, 2.9 GHz Processor       1
# Snapdragon  680 , Octa Core, 2.4 GHz Processor       1
# Snapdragon 835, Octa Core, 2.35 GHz Processor        1
# Google  Tensor 3, Octa Core Processor                1
# Name: count, Length: 275, dtype: int64

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt     267
# 6 GB RAM, 128 GB inbuilt     190
# 4 GB RAM, 64 GB inbuilt      143
# 12 GB RAM, 256 GB inbuilt     70
# 8 GB RAM, 256 GB inbuilt      70
# 4 GB RAM, 128 GB inbuilt      62
# 3 GB RAM, 32 GB inbuilt       37
# 6 GB RAM, 64 GB inbuilt       29
# 2 GB RAM, 32 GB inbuilt       24
# 3 GB RAM, 64 GB inbuilt       15
# 12 GB RAM, 512 GB inbuilt     10
# 6 GB RAM, 256 GB inbuilt       7
# 16 GB RAM, 256 GB inbuilt      6
# 4 GB RAM, 32 GB inbuilt        6
# 1 GB RAM, 16 GB inbuilt        6
# 6 GB RAM, 1 TB inbuilt         4
# 2 GB RAM, 16 GB inbuilt        4
# 2 GB RAM, 64 GB inbuilt        4
# 12 GB RAM, 128 GB inbuilt      4
# 6 GB RAM, 512 GB inbuilt       4
# 4 GB RAM, 256 GB inbuilt       3
# 16 GB RAM, 512 GB inbuilt      3
# 64 GB inbuilt                  2
# 3 GB RAM, 16 GB inbuilt        2
# 8 GB RAM, 512 GB inbuilt       2
# 1 GB RAM, 8 GB inbuilt         1
# 4 GB RAM, 512 GB inbuilt       1
# 18 GB RAM, 512 GB inbuilt      1
# ...

# %%
df1['battery'].value_counts()
# Out:
# battery
# 5000 mAh Battery with 33W Fast Charging      103
# 5000 mAh Battery with 18W Fast Charging       89
# 5000 mAh Battery                              74
# 5000 mAh Battery with 67W Fast Charging       30
# 5000 mAh Battery with 10W Fast Charging       28
#                                             ...
# 6000 mAh Battery with 120W Fast Charging       1
# 4600 mAh Battery with 240W Fast Charging       1
# 21000 mAh Battery with 33W Fast Charging       1
# 4200 mAh Battery with 66W Fast Charging        1
# 5000 mAh Battery with 68.2W Fast Charging      1
# Name: count, Length: 230, dtype: int64

# %%
df1['display'].value_counts()
# Out:
# display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole    54
# 6.5 inches, 720 x 1600 px Display with Water Drop Notch        36
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole     25
# 6.52 inches, 720 x 1600 px Display with Water Drop Notch       23
# 6.5 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole      22
#                                                                ..
# 6.92 inches, 1080 x 2460 px, 144 Hz Display                     1
# 6.51 inches, 1080 x 2408 px, 144 Hz Display with Punch Hole     1
# 6.2 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole      1
# 6.43 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole      1
# 6.8 inches, 1080 x 2400 px Display with Punch Hole              1
# Name: count, Length: 347, dtype: int64

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  40
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  38
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  34
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                            23
# 13 MP Rear & 5 MP Front Camera                                        20
#                                                                       ..
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera     1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                  1
# 48 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                   1
# 48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera            1
# Name: count, Length: 285, dtype: int64

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              354
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      89
# Memory Card (Hybrid)                    31
# Memory Card (Hybrid), upto 256 GB       15
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       7
# Memory Card Supported, upto 2 TB         5
# Memory Card Supported, upto 32 GB        4
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 2 TB          3
# Memory Card Supported, upto 1000 GB      1
# Name: count, dtype: int64

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                        394
# Android v11                        274
# Android v13                         91
# Android v10                         69
# Android v9.0 (Pie)                  29
# Android v10.0                       23
# iOS v16                             15
# iOS v15                             12
# Android v8.1 (Oreo)                 10
# iOS v14                              6
# Android v11.0                        4
# iOS v13                              4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# HarmonyOS v2.0                       2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# Harmony v2.0                         2
# EMUI v12                             2
# Android v12.1                        2
# iOS v14.0                            2
# HarmonyOS                            1
# Android                              1
# Hongmeng OS v4.0                     1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 1019
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      982 non-null    int64
#  1   model      982 non-null    object
#  2   price      982 non-null    int32
#  3   rating     879 non-null    float64
#  4   sim        982 non-null    object
#  5   processor  982 non-null    object
#  6   ram        982 non-null    object
#  7   battery    971 non-null    object
#  8   display    982 non-null    object
#  9   camera     982 non-null    object
#  10  card       982 non-null    object
#  11  os         967 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(9)
# memory usage: 128.2+ KB

# %%
df1.head()
# Out:
#    index                      model  price  rating  \
# 0      2              OnePlus 11 5G  54999    89.0
# 1      3  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4      Samsung Galaxy A14 5G  16499    75.0
# 3      5       Motorola Moto G62 5G  14999    81.0
# 4      6         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# ...

# %%
# lets make a new column named brand from model as you can see there is brand name infront of every column
brand_names = df['model'].str.split(' ').str.get(0)

# %%
# dataFrame.insert(index_position,'column_name',series_name)
df1.insert(1,'brand_name',brand_names)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    OnePlus              OnePlus 11 5G  54999    89.0
# 1      3    OnePlus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    Samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   Motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     Realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# ...

# %%
# lets convert brand_name into small letters beacause we have a chance like in someplaces like this 'SAMSUNG' and in other
# places as 'Samsung' this would be considered as two different values.

df1['brand_name'] = df1['brand_name'].str.lower()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\233834832.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['brand_name'] = df1['brand_name'].str.lower()

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# ...

# %% [markdown]
#     now lets go to sim column it has alot of information like dualsim,3G,4G,5G,VoLTE,Wi-Fi,NFC,IR Blaster
#     but if see clearly there is most of information that is true for many phone like nowadays most of the phone are Dual Sim
#     and 3G, 4G is also with a lot of people now-a-days the point of differentiation here is 5G which is not in all phones
#     2nd one NFC this is only available in highend phones
#     3rd one is IR Blaster even this is also not on majority of phones so i am considering these three as differentiating factors
#     now i am going to make three new columns from sim column
#         1)has 5g yes/no column
#         2)has NFC yes/no column
#         3)has IR Blaster yes/no column

# %%
df1['sim'].str.contains('5G')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1015    True
# 1016    True
# 1017    True
# 1018    True
# 1019    True
# Name: sim, Length: 982, dtype: bool

# %%
has_5g = df1['sim'].str.contains('5G')
has_nfc = df1['sim'].str.contains('NFC')
has_ir_blaster = df1['sim'].str.contains('IR Blaster')

# %%
df1.insert(6,'has_5g',has_5g)
df1.insert(7,'has_nfc',has_nfc)
df1.insert(8,'has_ir_blaster',has_ir_blaster)

# %%
# In the 'processor_brand' column, there is information about the processor name, number of cores, and processor speed, 
# separated by commas. Let's split this information into three separate columns.
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor                        ram  \
# ...

# %%
df1['processor'].str.split(',').str.get(0)
# Out:
# 0         Snapdragon 8 Gen2
# 1            Snapdragon 695
# 2               Exynos 1330
# 3           Snapdragon  695
# 4            Dimensity 1080
#                ...
# 1015      Snapdragon 8 Gen1
# 1016       Snapdragon  480+
# 1017         Dimensity 8100
# 1018         Snapdragon 695
# 1019    Octa Core Processor
# Name: processor, Length: 982, dtype: object

# %%
processor_name = df1['processor'].str.split(',').str.get(0)

# %%
num_cores = df1['processor'].str.split(',').str.get(1)

# %%
processor_speed = df1['processor'].str.split(',').str.get(2)

# %%
df1.insert(10,'processor_name',processor_name)
df1.insert(11,'num_cores',num_cores)
df1.insert(12,'processor_speed',processor_speed)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %%
df1['processor_name'].value_counts()
# if we observe the values their are some unrelated values they are
# Octa Core Processor         9
# Quad Core                   6
# Octa Core                   5
# SC9863A                     2
# (28 nm)                     1
# Out:
# processor_name
# Dimensity 700 5G      29
# Helio P35             28
# Snapdragon 8+ Gen1    26
# Snapdragon 8 Gen2     23
# Snapdragon 695        23
#                       ..
# Tiger T606             1
# Snapdragon 615         1
# Helio MT6580           1
# Helio  G95             1
# Google  Tensor 3       1
# Name: count, Length: 246, dtype: int64

# %%
df1['processor_name'] = df1['processor_name'].str.strip()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\1632474951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['processor_name'] = df1['processor_name'].str.strip()

# %%
df1[df1['processor_name'].str.contains('Core')]
# Out:
#       index brand_name                                 model  price  rating  \
# 118     120      tesla                        Tesla Pi Phone  69999    83.0
# 143     145        jio                           Jio Phone 3   4499     NaN
# 188     190      ikall                         iKall Z19 Pro   8099    60.0
# 201     203    samsung                    Samsung Galaxy A13  14450    75.0
# 309     311    samsung  Samsung Galaxy A13 (4GB RAM + 128GB)  14999    75.0
# 315     317       itel                          itel S16 Pro   6990     NaN
# 496     498    samsung                    Samsung Galaxy A15  15990    63.0
# 529     531    samsung                    Samsung Galaxy F14  14990    67.0
# 587     589    samsung  Samsung Galaxy A13 (6GB RAM + 128GB)  16499    78.0
# 758     760      ikall                             iKall Z19   7999    61.0
# 778     780      tecno                   Tecno Spark Go 2022   6249    61.0
# ...

# %%
df1[df1['processor_name'].str.contains('Core')][['processor_name','num_cores','processor_speed']]
# Out:
#            processor_name           num_cores processor_speed
# 118   Octa Core Processor                 NaN             NaN
# 143             Quad Core   1.4 GHz Processor             NaN
# 188             Quad Core   1.6 GHz Processor             NaN
# 201             Octa Core     2 GHz Processor             NaN
# 309             Octa Core     2 GHz Processor             NaN
# 315             Quad Core   1.3 GHz Processor             NaN
# 496   Octa Core Processor                 NaN             NaN
# 529   Octa Core Processor                 NaN             NaN
# 587             Octa Core     2 GHz Processor             NaN
# 758             Quad Core   1.6 GHz Processor             NaN
# 778             Octa Core   2.2 GHz Processor             NaN
# 794             Quad Core   1.3 GHz Processor             NaN
# 825   Octa Core Processor                 NaN             NaN
# 826   Octa Core Processor                 NaN             NaN
# ...

# %%
# one right shift
temp_df = df1[df1['processor_name'].str.contains('Core')][['processor_name','num_cores','processor_speed']].shift(1,axis = 1)

# %%
temp_df.index
# Out:
# Index([ 118,  143,  188,  201,  309,  315,  496,  529,  587,  758,  778,  794,
#         825,  826,  875,  948,  949,  991, 1005, 1019],
#       dtype='int64')

# %%
# loc[rows,columns] = values (to be inserted)
df1.loc[temp_df.index,['processor_name','num_cores','processor_speed']] = temp_df.values

# %%
df1[df1['processor_name'] == '(28 nm)']
# Out:
#      index brand_name                    model  price  rating  \
# 856    858    samsung  Samsung Galaxy A01 Core   4999     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 856  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
#
#                                  processor processor_name   num_cores  \
# 856  (28 nm), Quad Core, 1.5 GHz Processor        (28 nm)   Quad Core
#
#         processor_speed                      ram           battery  \
# 856   1.5 GHz Processor  1 GB RAM, 16 GB inbuilt  3000 mAh Battery
#
#                                display                         camera  \
# 856  5.3 inches, 720 x 1480 px Display  8 MP Rear & 5 MP Front Camera
#
#                       card           os
# 856  Memory Card Supported  Android v10

# %%
# Upon searching, I found out that the processor name "(28 nm)" is Mediatek MT6739, and I have replaced it.
df1['processor_name'] = df1['processor_name'].replace('(28 nm)','Mediatek MT6739')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\3157888763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['processor_name'] = df1['processor_name'].replace('(28 nm)','Mediatek MT6739')

# %%
df1[df1['processor_name'] == 'SC9863A']
# Out:
#      index brand_name                             model  price  rating  \
# 294    296     realme  Realme C11 2021 (4GB RAM + 64GB)   7749    61.0
# 972    974     realme                   Realme C11 2021   6499    61.0
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 294  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 972  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
#
#                                  processor processor_name   num_cores  \
# 294  SC9863A, Octa Core, 1.6 GHz Processor        SC9863A   Octa Core
# 972  SC9863A, Octa Core, 1.6 GHz Processor        SC9863A   Octa Core
#
#         processor_speed                      ram           battery  \
# 294   1.6 GHz Processor  4 GB RAM, 64 GB inbuilt  5000 mAh Battery
# 972   1.6 GHz Processor  2 GB RAM, 32 GB inbuilt  5000 mAh Battery
#
#                                                display  \
# 294  6.52 inches, 720 x 1600 px Display with Water ...
# ...

# %%
# Upon searching, I found out that the processor name "SC9863A" is 'Unisoc SC9863A', and I have replaced it. 
df1['processor_name'] = df1['processor_name'].replace('SC9863A','Unisoc SC9863A')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\433322200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['processor_name'] = df1['processor_name'].replace('SC9863A','Unisoc SC9863A')

# %%
df1.loc[972]
# Out:
# index                                                            974
# brand_name                                                    realme
# model                                                Realme C11 2021
# price                                                           6499
# rating                                                          61.0
# sim                                   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# has_5g                                                         False
# has_nfc                                                        False
# has_ir_blaster                                                 False
# processor                      SC9863A, Octa Core, 1.6 GHz Processor
# processor_name                                        Unisoc SC9863A
# num_cores                                                  Octa Core
# processor_speed                                    1.6 GHz Processor
# ram                                          2 GB RAM, 32 GB inbuilt
# ...

# %%
processor_brand = df1['processor_name'].str.split(' ').str.get(0).str.lower()

# %%
df1.insert(11,'processor_brand',processor_brand)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
#  Octa Core              866
#  Hexa Core               31
#  Quad Core               31
#  Octa Core Processor     19
# Octa Core Processor       9
#  Hexa Core Processor      8
# Quad Core                 6
# Octa Core                 5
# Name: count, dtype: int64

# %%
import math

def num_cores_converter(text):
    if isinstance(text, float) and not math.isnan(text):
        # Handle float values
        return int(text)  # Convert float to integer
    elif isinstance(text, str) and 'Octa' in text:
        return 8
    elif isinstance(text, str) and 'Hexa' in text:
        return 6
    elif isinstance(text, str) and 'Quad' in text:
        return 4
    # Add more conditions as needed
    else:
        return None  # or any default value you prefer

# %%
df1['num_cores'].apply(num_cores_converter).value_counts()
# Out:
# num_cores
# 8.0    899
# 6.0     39
# 4.0     37
# Name: count, dtype: int64

# %%
df1['num_cores'] = df1['num_cores'].apply(num_cores_converter)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\3020360321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['num_cores'] = df1['num_cores'].apply(num_cores_converter)

# %%
df1['num_cores'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 982 entries, 0 to 1019
# Series name: num_cores
# Non-Null Count  Dtype
# --------------  -----
# 975 non-null    float64
# dtypes: float64(1)
# memory usage: 47.6 KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 982 entries, 0 to 1019
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            982 non-null    int64
#  1   brand_name       982 non-null    object
#  2   model            982 non-null    object
#  3   price            982 non-null    int32
#  4   rating           879 non-null    float64
#  5   sim              982 non-null    object
#  6   has_5g           982 non-null    bool
#  7   has_nfc          982 non-null    bool
#  8   has_ir_blaster   982 non-null    bool
#  9   processor        982 non-null    object
#  10  processor_name   962 non-null    object
#  11  processor_brand  962 non-null    object
#  12  num_cores        975 non-null    float64
#  13  processor_speed  939 non-null    object
#  14  ram              982 non-null    object
#  15  battery          971 non-null    object
#  16  display          982 non-null    object
# ...

# %%
df1['processor_speed'].value_counts()
# Out:
# processor_speed
# 2 GHz Processor       146
# 2.2 GHz Processor     135
# 2.4 GHz Processor     128
# 3.2 GHz Processor      94
# 2.3 GHz Processor      86
# 3 GHz Processor        53
# 2.84 GHz Processor     36
# 2.05 GHz Processor     28
# 2.5 GHz Processor      23
# 1.8 GHz Processor      23
# 1.6 GHz Processor      20
# 2.85 GHz Processor     19
# 3.22 GHz Processor     18
# 3.1 GHz Processor      15
# 2.6 GHz Processor      14
# 2.9 GHz Processor      13
# 1.82 GHz Processor     10
# 1.3 GHz Processor      10
# 2.73 GHz Processor      9
# 2.8 GHz Processor       9
# 3.05 GHz Processor      8
# 2.36 GHz Processor      8
# 2.7 GHz Processor       5
# 1.4 GHz Processor       5
# 2.65 GHz Processor      5
# 1.5 GHz Processor       4
# 2.96 GHz Processor      3
# 2.86 GHz Processor      3
# 3.13 GHz Processor      2
# 1.1 GHz Processor       1
# 2.35 GHz Processor      1
# 2.37 GHz Processor      1
# 1.99 GHz Processor      1
# 1.95 GHz Processor      1
# 2.1 GHz Processor       1
# ...

# %%
# let us only take number
df1['processor_speed'].str.strip().str.split(' ').str.get(0)
# Out:
# 0        3.2 GHz
# 1        2.2 GHz
# 2        2.4 GHz
# 3        2.2 GHz
# 4        2.6 GHz
#           ...
# 1015       3 GHz
# 1016     2.2 GHz
# 1017    2.85 GHz
# 1018     2.2 GHz
# 1019         NaN
# Name: processor_speed, Length: 982, dtype: object

# %%
df1['processor_speed'].str.strip().str.split(' ').str.get(0)[0]
# Out:
# '3.2\u2009GHz'

# %%
df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\825004774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor     processor_name  \
# ...

# %%
# in ram column we have ram and internal memory together
df1['ram'].str.strip().str.split(',').str.get(0).str.split(' ')
# Out:
# 0       [12 GB, RAM]
# 1        [6 GB, RAM]
# 2        [4 GB, RAM]
# 3        [6 GB, RAM]
# 4        [6 GB, RAM]
#             ...
# 1015     [8 GB, RAM]
# 1016     [6 GB, RAM]
# 1017     [8 GB, RAM]
# 1018     [6 GB, RAM]
# 1019     [8 GB, RAM]
# Name: ram, Length: 982, dtype: object

# %%
df1['ram'].str.strip().str.split(',').str.get(0).str.split(' ').get(0)[0]
# Out:
# '12\u2009GB'

# %%
ram_capacity = df1['ram'].str.strip().str.split(',').str.get(0).str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram', 'battery',
#        'display', 'camera', 'card', 'os'],
#       dtype='object')

# %%
df1.insert(15,'ram_capacity',ram_capacity)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... processor_brand  \
# ...

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.strip().str.findall(r'\b(\d+)\b').str.get(0)

# %%
df1.insert(16,'internal_memory',internal_memory)

# %%
df1.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... num_cores  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...       8.0
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...       8.0
#
#   processor_speed                        ram  ram_capacity internal_memory  \
# 0             3.2  12 GB RAM, 256 GB inbuilt            12             256
# 1             2.2   6 GB RAM, 128 GB inbuilt             6             128
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# ...

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8      339
# 6      234
# 4      215
# 12      85
# 3       54
# 2       32
# 16       9
# 1        7
# 64       3
# 18       2
# 512      2
# Name: count, dtype: int64

# %%
df1['ram_capacity'] = df1['ram_capacity'].astype(float)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\2073605403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ram_capacity'] = df1['ram_capacity'].astype(float)

# %%
df1[df1['ram_capacity'] > 18]
# Out:
#      index brand_name                             model   price  rating  \
# 439    441      apple            Apple iPhone SE 3 2022   43900     NaN
# 483    485     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488      nokia                     Nokia 8000 4G    6899     NaN
# 627    629      nokia                      Nokia 225 4G    3589     NaN
# 762    764      apple                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  has_5g  has_nfc  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 486                          Dual Sim, 3G, 4G, Wi-Fi   False    False
# 627                          Dual Sim, 3G, 4G, VoLTE   False    False
# 762          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster                                         processor  ...  \
# ...

# %%
df1.loc[[439,762],['ram_capacity','internal_memory']] = [[4.0,'64'],[4.0,'64']]

# %%
df1[df1['ram_capacity'] > 18]
# Out:
#      index brand_name                             model   price  rating  \
# 483    485     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 486    488      nokia                     Nokia 8000 4G    6899     NaN
# 627    629      nokia                      Nokia 225 4G    3589     NaN
#
#                                                  sim  has_5g  has_nfc  \
# 483  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 486                          Dual Sim, 3G, 4G, Wi-Fi   False    False
# 627                          Dual Sim, 3G, 4G, VoLTE   False    False
#
#      has_ir_blaster                                         processor  ...  \
# 483            True  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  ...
# 486           False     Snapdragon  210, Quad Core, 1.1 GHz Processor  ...
# 627           False                                       Unisoc T117  ...
#
#     num_cores processor_speed                        ram  ram_capacity  \
# ...

# %%
df1.loc[[483],['ram_capacity','internal_memory']] = [12.0,'512']

# %%
df1[df1['ram_capacity'] > 18]
# as you can see in output they are feature phone as we only need smartphone data lets remove them
# Out:
#      index brand_name          model  price  rating                      sim  \
# 486    488      nokia  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
# 627    629      nokia   Nokia 225 4G   3589     NaN  Dual Sim, 3G, 4G, VoLTE
#
#      has_5g  has_nfc  has_ir_blaster  \
# 486   False    False           False
# 627   False    False           False
#
#                                          processor  ... num_cores  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor  ...       4.0
# 627                                    Unisoc T117  ...       NaN
#
#     processor_speed                        ram  ram_capacity internal_memory  \
# 486             1.1   512 MB RAM, 4 GB inbuilt         512.0               4
# 627             NaN  64 MB RAM, 128 MB inbuilt          64.0             128
#
#               battery                           display              camera  \
# 486  1500 mAh Battery  2.8 inches, 240 x 320 px Display    2 MP Rear Camera
# ...

# %%
# they are not smartphones they are feature phones
df1.drop([486,627],inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\1964638788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop([486,627],inplace = True)

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8.0     339
# 6.0     234
# 4.0     217
# 12.0     86
# 3.0      54
# 2.0      32
# 16.0      9
# 1.0       7
# 18.0      2
# Name: count, dtype: int64

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 128    523
# 64     193
# 256    157
# 32      67
# 512     22
# 16      12
# 1        5
# 8        1
# Name: count, dtype: int64

# %%
df1['internal_memory'] = df1['internal_memory'].astype(float)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\3988935729.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['internal_memory'] = df1['internal_memory'].astype(float)

# %%
df1[df1['internal_memory'] < 32]
# Out:
#      index brand_name                                     model   price  \
# 290    292      apple             Apple iPhone 14 Pro Max (1TB)  182999
# 399    401       itel                                  itel P36    6490
# 477    479       vivo                                  Vivo Y25    7499
# 574    576       vivo                                  Vivo Y71   25000
# 735    737      tecno                            Tecno Pop 5 Go    6999
# 738    740      nokia                            Nokia C01 Plus    5249
# 744    746       itel                                  itel S16    5990
# 781    783      apple             Apple iPhone 13 Pro Max (1TB)  179900
# 794    796       itel                                  itel A56    5490
# 814    816      apple                 Apple iPhone 14 Pro (1TB)  172999
# 844    846        cat                              CAT S22 Flip   14999
# 856    858    samsung                   Samsung Galaxy A01 Core    4999
# ...

# %%
df1[df1['internal_memory'] == 1]
# as you can see where ever internal_memory is 1 it is not GB, it is TB
# Out:
#      index brand_name                                     model   price  \
# 290    292      apple             Apple iPhone 14 Pro Max (1TB)  182999
# 781    783      apple             Apple iPhone 13 Pro Max (1TB)  179900
# 814    816      apple                 Apple iPhone 14 Pro (1TB)  172999
# 943    945    samsung  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980
# 961    963      apple                 Apple iPhone 13 Pro (1TB)  147900
#
#      rating                                      sim  has_5g  has_nfc  \
# 290    78.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 781    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 814    77.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 943     NaN  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 961    84.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster                                          processor  ...  \
# ...

# %%
temp_df = df1[df1['internal_memory'] == 1]

# %%
df1.loc[temp_df.index,'internal_memory'] = 1024

# %%
df1[df1['internal_memory'] == 1]
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor, processor_name, processor_brand, num_cores, processor_speed, ram, ram_capacity, internal_memory, battery, display, camera, card, os]
# Index: []
#
# [0 rows x 22 columns]

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 128.0     523
# 64.0      193
# 256.0     157
# 32.0       67
# 512.0      22
# 16.0       12
# 1024.0      5
# 8.0         1
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... num_cores  \
# ...

# %%
# In battery column we have two information one is battery_capacity and second one whether it has fast charging or not if there
# is fast charging then what are the Watts if there is not fast charging we will consider it as '0'watts. 
# lets make 2 columns from this 1st battery capacity, 2nd fast charging watts if there is no fast charging then 0 watts
# as you can see values in column are breaking at with

df1['battery'].str.strip().str.split('with')

# as you can see in the output there are 2 values in most of the places but only one in few places not all have fast charging
# Out:
# 0        [5000 mAh Battery ,  100W Fast Charging]
# 1         [5000 mAh Battery ,  33W Fast Charging]
# 2         [5000 mAh Battery ,  15W Fast Charging]
# 3             [5000 mAh Battery ,  Fast Charging]
# 4         [5000 mAh Battery ,  67W Fast Charging]
#                           ...
# 1015    [5000 mAh Battery ,  68.2W Fast Charging]
# 1016    [5000 mAh Battery ,  22.5W Fast Charging]
# 1017      [5080 mAh Battery ,  67W Fast Charging]
# 1018          [5000 mAh Battery ,  Fast Charging]
# 1019          [5000 mAh Battery ,  Fast Charging]
# Name: battery, Length: 980, dtype: object

# %%
df1['battery'].str.strip().str.split('with').str.get(0).str.strip().str.split(' ').get(0)
# Out:
# ['5000\u2009mAh', 'Battery']

# %%
df1['battery'].str.strip().str.split('with').str.get(0).str.strip().str.findall(r'\b(\d+)\b').str.get(0)
# Out:
# 0       5000
# 1       5000
# 2       5000
# 3       5000
# 4       5000
#         ...
# 1015    5000
# 1016    5000
# 1017    5080
# 1018    5000
# 1019    5000
# Name: battery, Length: 980, dtype: object

# %%
battery_capacity = df1['battery'].str.strip().str.split('with').str.get(0).str.strip().str.findall(r'\b(\d+)\b').str.get(0).astype(float)

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram',
#        'ram_capacity', 'internal_memory', 'battery', 'display', 'camera',
#        'card', 'os'],
#       dtype='object')

# %%
df1.insert(18,'battery_capacity',battery_capacity)

# %%
df1['battery'].str.strip().str.split('with').str.get(1)
# Out:
# 0         100W Fast Charging
# 1          33W Fast Charging
# 2          15W Fast Charging
# 3              Fast Charging
# 4          67W Fast Charging
#                 ...
# 1015     68.2W Fast Charging
# 1016     22.5W Fast Charging
# 1017       67W Fast Charging
# 1018           Fast Charging
# 1019           Fast Charging
# Name: battery, Length: 980, dtype: object

# %%
fast_charging = df1['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')

# %%
df1.insert(18,'fast_charging',fast_carging)

# %%
df1['battery_capacity'].value_counts()
# Out:
# battery_capacity
# 5000.0    487
# 4500.0     97
# 6000.0     60
# 4000.0     42
# 4700.0     27
#          ...
# 4730.0      1
# 3520.0      1
# 4080.0      1
# 5600.0      1
# 8000.0      1
# Name: count, Length: 89, dtype: int64

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_carging
# [33]     152
# [18]     128
# []        68
# [67]      65
# [25]      53
# [120]     46
# [15]      43
# [80]      42
# [66]      37
# [10]      33
# [30]      32
# [65]      30
# [44]      23
# [45]      17
# [20]      10
# [68]       8
# [100]      7
# [150]      7
# [125]      6
# [40]       5
# [22]       5
# [60]       4
# [55]       3
# [50]       2
# [210]      2
# [21]       2
# [180]      1
# [200]      1
# [240]      1
# [19]       1
# [135]      1
# [165]      1
# [27]       1
# Name: count, dtype: int64

# %%
def fast_charging_extractor(item):
    if type(item) == list:
        if len(item) == 1:
            return item[0]
        else:
            return 0
    else:
        return -1

# %%
df1['fast_charging'] = df1['fast_charging'].apply(fast_charging_extractor).astype(int)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\2190291321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['fast_carging'] = df1['fast_carging'].apply(fast_charging_extractor).astype(int)

# %%
# df1.rename(columns={'fast_carging': 'fast_charging'}, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\314112596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'fast_carging': 'fast_charging'}, inplace=True)

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
#  33     152
# -1      143
#  18     128
#  0       68
#  67      65
#  25      53
#  120     46
#  15      43
#  80      42
#  66      37
#  10      33
#  30      32
#  65      30
#  44      23
#  45      17
#  20      10
#  68       8
#  100      7
#  150      7
#  125      6
#  40       5
#  22       5
#  60       4
#  55       3
#  50       2
#  210      2
#  21       2
#  180      1
#  200      1
#  240      1
#  19       1
#  135      1
#  165      1
#  27       1
# Name: count, dtype: int64

# %%
df1['fast_charging'] = df1['fast_charging'].replace(0,np.nan).replace(-1,np.nan)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\2706776876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['fast_charging'] = df1['fast_charging'].replace(0,np.nan).replace(-1,np.nan)

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
# 33.0     152
# 18.0     128
# 67.0      65
# 25.0      53
# 120.0     46
# 15.0      43
# 80.0      42
# 66.0      37
# 10.0      33
# 30.0      32
# 65.0      30
# 44.0      23
# 45.0      17
# 20.0      10
# 68.0       8
# 100.0      7
# 150.0      7
# 125.0      6
# 22.0       5
# 40.0       5
# 60.0       4
# 55.0       3
# 21.0       2
# 210.0      2
# 50.0       2
# 180.0      1
# 200.0      1
# 240.0      1
# 19.0       1
# 135.0      1
# 165.0      1
# 27.0       1
# Name: count, dtype: int64

# %%
df1.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ...  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...
#
#                          ram ram_capacity  internal_memory  \
# 0  12 GB RAM, 256 GB inbuilt         12.0            256.0
# 1   6 GB RAM, 128 GB inbuilt          6.0            128.0
#
#                                     battery fast_charging  battery_capacity  \
# 0  5000 mAh Battery with 100W Fast Charging         100.0            5000.0
# ...

# %%
def fast_charging_extractor(text):
    if text is None:
        return 0  
    if 'Fast Charging' in text:
        return 1
    else:
        return 0

# %%
fast_charging_available = df1['battery']

# %%
fast_charging_available = fast_charging_available.apply(fast_charging_extractor)

# %%
fast_charging_available.value_counts()
# Out:
# battery
# 1    837
# 0    143
# Name: count, dtype: int64

# %%
df1.insert(18,'fast_charging_available',fast_charging_available)

# %%
df1.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... ram_capacity  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...         12.0
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...          6.0
#
#   internal_memory                                   battery  \
# 0           256.0  5000 mAh Battery with 100W Fast Charging
# 1           128.0   5000 mAh Battery with 33W Fast Charging
#
#    fast_charging_available fast_charging  battery_capacity  \
# 0                        1         100.0            5000.0
# ...

# %%
screen_size = df1['display'].str.strip().str.split(',').str.get(0).str.split(' ').str.get(0).astype(float)

# %%
df1.insert(21,'screen_size',screen_size)

# %%
resolution = df1['display'].str.strip().str.split(',').str.get(1).str.split('px').str.get(0)

# %%
df1.insert(22,'resolution',resolution)

# %%
df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0)
# Out:
# 0       120
# 1       120
# 2        90
# 3       120
# 4       120
#        ...
# 1015    120
# 1016    NaN
# 1017    144
# 1018    NaN
# 1019    NaN
# Name: display, Length: 980, dtype: object

# %%
# where ever there isn't a refresh rate it will become 60 according to industry standards
refresh_rate = df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0).apply(lambda x:60 if pd.isna(x) else x).astype(int)

# %%
df1.insert(22,'refresh_rate',refresh_rate)

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  40
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  38
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  34
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                            23
# 12 MP + 12 MP Dual Rear & 12 MP Front Camera                          20
#                                                                       ..
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera     1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                  1
# 48 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                   1
# 48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera            1
# Name: count, Length: 284, dtype: int64

# %%
df1['camera'].str.strip().str.split('&').str.get(0)
# Out:
# 0             50 MP + 48 MP + 32 MP Triple Rear
# 1               64 MP + 2 MP + 2 MP Triple Rear
# 2               50 MP + 2 MP + 2 MP Triple Rear
# 3               50 MP + 8 MP + 2 MP Triple Rear
# 4              108 MP + 8 MP + 2 MP Triple Rear
#                           ...
# 1015            64 MP + 8 MP + 2 MP Triple Rear
# 1016    48 MP + 2 MP + Depth Sensor Triple Rear
# 1017            64 MP + 8 MP + 2 MP Triple Rear
# 1018           108 MP + 8 MP + 2 MP Triple Rear
# 1019            64 MP + 8 MP + 5 MP Triple Rear
# Name: camera, Length: 980, dtype: object

# %%
def camera_extractor(text):
    if 'Quad' in text:
        return 4
    elif 'Triple' in text:
        return 3
    elif 'Dual' in text:
        return 2
    else:
        return 1

# %%
num_rear_cameras = df1['camera'].str.strip().str.split('&').str.get(0).apply(camera_extractor)

# %%
df1.insert(25,'num_rear_cameras',num_rear_cameras)

# %%
def camera_extractor_f(text):
    if 'Quad' in text:
        return 4
    elif 'Triple' in text:
        return 3
    elif 'Dual' in text:
        return 2
    elif 'missing' in text:
        return 'missing'
    else:
        return 1

# %%
num_front_cameras = df1['camera'].str.strip().str.split('&').str.get(1).str.strip().fillna('missing').apply(camera_extractor_f)

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... fast_charging  \
# ...

# %%
df1.insert(26,'num_front_cameras',num_front_cameras)

# %%
df1.head(2)
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... battery_capacity  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  ...           5000.0
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor  ...           5000.0
#
#   screen_size  refresh_rate     resolution  \
# 0        6.70           120   1440 x 3216
# 1        6.59           120   1080 x 2412
#
#                                              display  num_rear_cameras  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...                 3
# ...

# %%
df1[df1['num_front_cameras'] == 'missing']
# Out:
#       index brand_name                model   price  rating  \
# 69       71       oppo     Oppo Find N Fold   99990     NaN
# 462     464     xiaomi  Xiaomi Mi Mix Alpha  199990     NaN
# 993     995     huawei        Huawei Mate X  169000     NaN
# 1012   1014       itel            itel A23s    4787     NaN
#
#                                                     sim  has_5g  has_nfc  \
# 69              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 462                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...    True     True
# 1012                            Dual Sim, 3G, 4G, Wi-Fi   False    False
#
#       has_ir_blaster                                          processor  ...  \
# 69             False  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor  ...
# 462            False     Snapdragon 855+, Octa Core, 2.96 GHz Processor  ...
# ...

# %%
df1.head()
# Out:
#    index brand_name                      model  price  rating  \
# 0      2    oneplus              OnePlus 11 5G  54999    89.0
# 1      3    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4    samsung      Samsung Galaxy A14 5G  16499    75.0
# 3      5   motorola       Motorola Moto G62 5G  14999    81.0
# 4      6     realme         Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                          processor  ... battery_capacity  \
# ...

# %%
df1[df1['camera'] == 'Foldable Display, Dual Display']
# Out:
#     index brand_name             model  price  rating  \
# 69     71       oppo  Oppo Find N Fold  99990     NaN
#
#                                         sim  has_5g  has_nfc  has_ir_blaster  \
# 69  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
#
#                                             processor  ... battery_capacity  \
# 69  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor  ...           5000.0
#
#    screen_size  refresh_rate     resolution  \
# 69         7.1           120   1792 x 1920
#
#                                               display  num_rear_cameras  \
# 69  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...                 2
#
#     num_front_cameras                          camera  \
# 69            missing  Foldable Display, Dual Display
#
#                          card           os
# 69  Memory Card Not Supported  Android v12
#
# [1 rows x 30 columns]

# %%
temp_df = df1[df1['camera'] == 'Foldable Display, Dual Display']

# %%
df1.loc[temp_df.index,'camera'] = '50'

# %%
df1['camera'].str.split( ).str.get(0)
# Out:
# 0        50
# 1        64
# 2        50
# 3        50
# 4       108
#        ...
# 1015     64
# 1016     48
# 1017     64
# 1018    108
# 1019     64
# Name: camera, Length: 980, dtype: object

# %%
primary_camera_rare = df1['camera'].str.split( ).str.get(0)

# %%
df1.columns
# Out:
# Index(['index', 'brand_name', 'model', 'price', 'rating', 'sim', 'has_5g',
#        'has_nfc', 'has_ir_blaster', 'processor', 'processor_name',
#        'processor_brand', 'num_cores', 'processor_speed', 'ram',
#        'ram_capacity', 'internal_memory', 'battery', 'fast_charging_available',
#        'fast_charging', 'battery_capacity', 'screen_size', 'refresh_rate',
#        'resolution', 'display', 'num_rear_cameras', 'num_front_cameras',
#        'camera', 'card', 'os'],
#       dtype='object')

# %%
df1.insert(27,'primary_camera_rare',primary_camera_rare)

# %%
df1['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.
replace('\u2009',' ').str.split(' ').str.get(0)
# Out:
# 0       16
# 1       16
# 2       13
# 3       16
# 4       16
#         ..
# 1015    16
# 1016     8
# 1017    16
# 1018    32
# 1019    32
# Name: camera, Length: 980, dtype: object

# %%
primary_camera_front = df1['camera'].str.split('&').str.get(1).str.strip().str.
split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1.insert(28,'primary_camera_front',primary_camera_front)

# %%
df1.head(20)
# Out:
#     index brand_name                                    model   price  rating  \
# 0       2    oneplus                            OnePlus 11 5G   54999    89.0
# 1       3    oneplus                OnePlus Nord CE 2 Lite 5G   19989    81.0
# 2       4    samsung                    Samsung Galaxy A14 5G   16499    75.0
# 3       5   motorola                     Motorola Moto G62 5G   14999    81.0
# 4       6     realme                       Realme 10 Pro Plus   24999    82.0
# 5       7    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)   16999    80.0
# 6       8      apple                          Apple iPhone 14   65999    81.0
# 7       9     xiaomi            Xiaomi Redmi Note 12 Pro Plus   29999    86.0
# 8      10    nothing                          Nothing Phone 1   26749    85.0
# 9      11    oneplus                       OnePlus Nord 2T 5G   28999    84.0
# 10     12     realme                            Realme 10 Pro   18999    82.0
# ...

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              354
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported, upto 256 GB      89
# Memory Card Supported                   88
# Memory Card (Hybrid)                    31
# Memory Card (Hybrid), upto 256 GB       15
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       7
# Memory Card Supported, upto 2 TB         5
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card Supported, upto 32 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 2 TB          3
# Memory Card Supported, upto 1000 GB      1
# Name: count, dtype: int64

# %%
df1['card'].str.split('upto').str.get(1).value_counts()
# Out:
# card
# 1 TB       262
# 512 GB     116
# 256 GB     104
# 128 GB      10
# 2 TB         8
# 32 GB        3
# 64 GB        3
# 1000 GB      1
# Name: count, dtype: int64

# %%
df1['card'].str.split('upto').str.get(1).str.strip()
# Out:
# 0        NaN
# 1       1 TB
# 2       1 TB
# 3       1 TB
# 4        NaN
#         ...
# 1015     NaN
# 1016    1 TB
# 1017     NaN
# 1018    1 TB
# 1019    1 TB
# Name: card, Length: 980, dtype: object

# %%
def card_extention_extractor(text):
    if isinstance(text, str):
        if 'GB' in text:
            return text.replace('GB','')
        elif 'TB' in text:
            return str(float(text.replace('TB','')) * 1024)
        else:
            return np.nan
    else:
        return np.nan

# %%
extended_upto = df1['card'].str.split('upto').str.get(1).str.strip().apply(card_extention_extractor)

# %%
extended_upto.value_counts()
# Out:
# card
# 1024.0    262
# 512       116
# 256       104
# 128        10
# 2048.0      8
# 32          3
# 64          3
# 1000        1
# Name: count, dtype: int64

# %%
extended_upto.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 980 entries, 0 to 1019
# Series name: card
# Non-Null Count  Dtype
# --------------  -----
# 507 non-null    object
# dtypes: object(1)
# memory usage: 47.6+ KB

# %%
extended_upto.value_counts().sum()
# Out:
# 507

# %%
extended_upto.dtype
# Out:
# dtype('O')

# %%
extended_upto = extended_upto.astype(float)

# %%
extended_upto.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 980 entries, 0 to 1019
# Series name: card
# Non-Null Count  Dtype
# --------------  -----
# 507 non-null    float64
# dtypes: float64(1)
# memory usage: 47.6 KB

# %%
extended_upto.dtype
# Out:
# dtype('float64')

# %%
extended_upto.value_counts()
# Out:
# card
# 1024.0    262
# 512.0     116
# 256.0     104
# 128.0      10
# 2048.0      8
# 32.0        3
# 64.0        3
# 1000.0      1
# Name: count, dtype: int64

# %%
df1.insert(30,'extended_upto',extended_upto)

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              354
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported, upto 256 GB      89
# Memory Card Supported                   88
# Memory Card (Hybrid)                    31
# Memory Card (Hybrid), upto 256 GB       15
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       7
# Memory Card Supported, upto 2 TB         5
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card Supported, upto 32 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 2 TB          3
# Memory Card Supported, upto 1000 GB      1
# Name: count, dtype: int64

# %%
df1['card'].str.split(',').str.get(0).str.strip().value_counts()
# Out:
# card
# Memory Card Supported        469
# Memory Card Not Supported    354
# Memory Card (Hybrid)         157
# Name: count, dtype: int64

# %%
def extended_memory_available_extractor(text):
    if text == 'Memory Card Not Supported':
        return 0
    else:
        return 1

# %%
extended_memory_available = df1['card'].str.split(',').str.get(0).str.strip().apply(extended_memory_available_extractor)

# %%
extended_memory_available.value_counts()
# Out:
# card
# 1    626
# 0    354
# Name: count, dtype: int64

# %%
extended_memory_available.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 980 entries, 0 to 1019
# Series name: card
# Non-Null Count  Dtype
# --------------  -----
# 980 non-null    int64
# dtypes: int64(1)
# memory usage: 47.6 KB

# %%
df1.insert(30,'extended_memory_available',extended_memory_available)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 980 entries, 0 to 1019
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      980 non-null    int64
#  1   brand_name                 980 non-null    object
#  2   model                      980 non-null    object
#  3   price                      980 non-null    int32
#  4   rating                     879 non-null    float64
#  5   sim                        980 non-null    object
#  6   has_5g                     980 non-null    bool
#  7   has_nfc                    980 non-null    bool
#  8   has_ir_blaster             980 non-null    bool
#  9   processor                  980 non-null    object
#  10  processor_name             960 non-null    object
#  11  processor_brand            960 non-null    object
#  12  num_cores                  974 non-null    float64
# ...

# %%
cols_to_drop = ['index','sim','processor','ram','battery','display','camera','card']

# %%
df1.drop(columns = cols_to_drop,inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\2863092275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns = cols_to_drop,inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 980 entries, 0 to 1019
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int32
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_name             960 non-null    object
#  8   processor_brand            960 non-null    object
#  9   num_cores                  974 non-null    float64
#  10  processor_speed            938 non-null    float64
#  11  ram_capacity               980 non-null    float64
#  12  internal_memory            980 non-null    float64
# ...

# %%
df1.num_front_cameras.value_counts()
# Out:
# num_front_cameras
# 1          947
# 2           29
# missing      4
# Name: count, dtype: int64

# %%
df1.num_front_cameras.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 980 entries, 0 to 1019
# Series name: num_front_cameras
# Non-Null Count  Dtype
# --------------  -----
# 980 non-null    object
# dtypes: object(1)
# memory usage: 47.6+ KB

# %%
df1['num_front_cameras'].value_counts()
# Out:
# num_front_cameras
# 1          947
# 2           29
# missing      4
# Name: count, dtype: int64

# %%
df1['num_front_cameras'] = df1['num_front_cameras'].replace('missing',np.nan)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\1101658814.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1['num_front_cameras'] = df1['num_front_cameras'].replace('missing',np.nan)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\1101658814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['num_front_cameras'] = df1['num_front_cameras'].replace('missing',np.nan)

# %%
df1['num_cores'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 980 entries, 0 to 1019
# Series name: num_cores
# Non-Null Count  Dtype
# --------------  -----
# 974 non-null    float64
# dtypes: float64(1)
# memory usage: 47.6 KB

# %%
df2 = df1.copy()  # Creating a copy of the DataFrame
df1['num_front_cameras'] = df1['num_front_cameras'].astype(float)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\1841982963.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['num_front_cameras'] = df1['num_front_cameras'].astype(float)

# %%
# primary_camera_rear
df1.rename(columns = {'primary_camera_rare':'primary_camera_rear'}, inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\3978035761.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns = {'primary_camera_rare':'primary_camera_rear'}, inplace = True)

# %%
df1['primary_camera_rear'].value_counts()
# Out:
# primary_camera_rear
# 50      333
# 64      181
# 13      116
# 48      114
# 108      80
# 12       57
# 8        39
# 200      18
# 16       17
# 5         6
# 12.2      4
# 54        3
# 50.3      3
# 20        3
# 2         2
# 24        2
# 47.2      1
# 40        1
# Name: count, dtype: int64

# %%
df1['primary_camera_rear'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 980 entries, 0 to 1019
# Series name: primary_camera_rear
# Non-Null Count  Dtype
# --------------  -----
# 980 non-null    object
# dtypes: object(1)
# memory usage: 47.6+ KB

# %%
df1['primary_camera_rear'] = pd.to_numeric(df1['primary_camera_rear'],errors = 'coerce')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\4018837920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['primary_camera_rear'] = pd.to_numeric(df1['primary_camera_rear'],errors = 'coerce')

# %%
df1['primary_camera_rear'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 980 entries, 0 to 1019
# Series name: primary_camera_rear
# Non-Null Count  Dtype
# --------------  -----
# 980 non-null    float64
# dtypes: float64(1)
# memory usage: 47.6 KB

# %%
df1['primary_camera_front'].value_counts()
# Out:
# primary_camera_front
# 16      307
# 8       178
# 32      155
# 5       119
# 12       50
# 13       41
# 20       37
# 10       24
# 50       12
# 60       10
# 44        8
# 40        6
# 2         5
# 7         5
# 24        3
# 25        3
# 10.8      3
# 48        2
# 11.1      2
# 0.3       1
# 2.1       1
# Main      1
# 10.7      1
# 10.1      1
# 12.6      1
# Name: count, dtype: int64

# %%
df1['primary_camera_front'].replace('Main', np.nan, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\3127670352.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['primary_camera_front'].replace('Main', np.nan, inplace=True)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\3127670352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df1['primary_camera_front'].value_counts()
# Out:
# primary_camera_front
# 16      307
# 8       178
# 32      155
# 5       119
# 12       50
# 13       41
# 20       37
# 10       24
# 50       12
# 60       10
# 44        8
# 40        6
# 2         5
# 7         5
# 24        3
# 25        3
# 10.8      3
# 48        2
# 11.1      2
# 0.3       1
# 2.1       1
# 10.7      1
# 10.1      1
# 12.6      1
# Name: count, dtype: int64

# %%
df1['primary_camera_front'] = pd.to_numeric(df1['primary_camera_front'], errors = 'coerce')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\899355318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['primary_camera_front'] = pd.to_numeric(df1['primary_camera_front'], errors = 'coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 980 entries, 0 to 1019
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int32
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_name             960 non-null    object
#  8   processor_brand            960 non-null    object
#  9   num_cores                  974 non-null    float64
#  10  processor_speed            938 non-null    float64
#  11  ram_capacity               980 non-null    float64
#  12  internal_memory            980 non-null    float64
# ...

# %%
df1[['processor_name','processor_brand']]
# Out:
#          processor_name processor_brand
# 0     Snapdragon 8 Gen2      snapdragon
# 1        Snapdragon 695      snapdragon
# 2           Exynos 1330          exynos
# 3       Snapdragon  695      snapdragon
# 4        Dimensity 1080       dimensity
# ...                 ...             ...
# 1015  Snapdragon 8 Gen1      snapdragon
# 1016   Snapdragon  480+      snapdragon
# 1017     Dimensity 8100       dimensity
# 1018     Snapdragon 695      snapdragon
# 1019               None            None
#
# [980 rows x 2 columns]

# %%
df1.drop(columns = 'processor_name',inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\2425547338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns = 'processor_name',inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 980 entries, 0 to 1019
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int32
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  ram_capacity               980 non-null    float64
#  11  internal_memory            980 non-null    float64
#  12  fast_charging_available    980 non-null    int64
# ...

# %%
df1['ram_capacity'] = df1['ram_capacity'].astype(int)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\939364677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['ram_capacity'] = df1['ram_capacity'].astype(int)

# %%
df1['internal_memory'] = df1['internal_memory'].astype(int)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\429351942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['internal_memory'] = df1['internal_memory'].astype(int)

# %%
df['os'].value_counts()
# Out:
# os
# Android v12                           287
# Android v11                           233
# No FM Radio                           192
# Android v10                            58
# Android v13                            45
# Bluetooth                              38
# Android v9.0 (Pie)                     27
# Android v10.0                          22
# iOS v16                                14
# iOS v15                                10
# Android v8.1 (Oreo)                    10
# Memory Card Not Supported               6
# Android v11.0                           4
# Browser                                 4
# Android v8.0 (Oreo)                     4
# iOS v13                                 3
# Android v6.0 (Marshmallow)              3
# iOS v15.0                               3
# Memory Card Supported, upto 32 GB       3
# Android v5.1.1 (Lollipop)               2
# Memory Card (Hybrid), upto 2 TB         2
# Harmony v2.0                            2
# ...

# %%
df[df['os'].isnull()]
# Out:
#                              model    price  rating  \
# 473                   Nokia 110 4G   ₹1,762     NaN
# 532  Samsung Guru Music 2 Dual Sim   ₹1,949     NaN
# 573               Nokia 105 (2019)   ₹1,299     NaN
# 608              Namotel Achhe Din      ₹99     NaN
# 640                 Nokia 105 Plus   ₹1,299     NaN
# 645                Nokia 2760 Flip   ₹5,490     NaN
# 647              Motorola Moto A10   ₹1,339     NaN
# 657                  Zanco Tiny T1   ₹2,799     NaN
# 665                   itel it2163S     ₹958     NaN
# 699          Samsung Guru GT-E1215   ₹1,850     NaN
# 748                   Nokia 400 4G   ₹3,290     NaN
# 757                   Karbonn KU3i     ₹995     NaN
# 835                 Eunity U1 King     ₹599     NaN
# 857                    LG Folder 2  ₹11,999     NaN
# 881               Nokia 110 (2022)   ₹1,599     NaN
# 927             Samsung Guru E1200   ₹1,685     NaN
# 932                 Eunity U1 Livo     ₹649     NaN
#
# ...

# %%
df[df['os'] == 'NaN'].count()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017    False
# 1018    False
# 1019    False
# Name: os, Length: 1020, dtype: bool

# %%
def os_extracter(text):
    if isinstance(text, str):
        if 'Android' in text:
            return 'Android'
        elif 'iOS' in text:
            return 'iOS'
        elif text == '0':
            return '0'
        else:
            return 'Other'
    else:
        return 'Unknown'

# %%
# Convert NaN values to empty strings
df1['os'] = df1['os'].fillna('0')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\2242789625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['os'] = df1['os'].fillna('0')

# %%
# Apply the function to the 'os' column
df1['os'] = df1['os'].apply(os_extracter)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5964\3677418546.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['os'] = df1['os'].apply(os_extracter)

# %%
df1['os'].value_counts()
# Out:
# os
# Android    910
# iOS         46
# 0           14
# Other       10
# Name: count, dtype: int64

# %%
df1['os'].replace('0',np.nan).value_counts()
# Out:
# os
# Android    910
# iOS         46
# Other       10
# Name: count, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 980 entries, 0 to 1019
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int32
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  ram_capacity               980 non-null    int32
#  11  internal_memory            980 non-null    int32
#  12  fast_charging_available    980 non-null    int64
# ...

# %%
# df1.to_csv('smartphones_cleaned.csv',index = False)
